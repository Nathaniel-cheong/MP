# %%
import re
import pdfplumber

def extract_section_with_layout(pdf_path: str, section_code: str, section_title: str) -> str:
    """
    Finds the specified section by plain-text scan (no layout=True),
    locates the 'Reqd. QTY' start of the main table, then finds the
    next section header to mark the end. Finally re-extracts that
    range in layout mode to preserve spacing.
    """
    code = section_code.upper()
    title = section_title.upper()

    # Patterns
    next_sec_re     = re.compile(r'^[A-Z]+-\d+', re.IGNORECASE)
    table_header_re = re.compile(r'\bReqd\.?\s*QTY\b', re.IGNORECASE)

    # Phase 1: plain-text scan to find start_page, header_hit, end_page
    start_page = None
    header_hit = False
    end_page   = None

    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages):
            text = page.extract_text() or ""
            for ln in text.splitlines():
                up = ln.strip().upper()
                if start_page is None:
                    # Detect section header (FRAMEGROUP or simple)
                    if ("FRAMEGROUP" in up and up.startswith(code) and title in up) or \
                       (up.startswith(code) and title in up):
                        start_page = i
                        break
                elif not header_hit:
                    # Detect the table header
                    if table_header_re.search(up):
                        header_hit = True
                    # continue scanning same page to look for end only after header
                else:
                    # after header, detect next section
                    if next_sec_re.match(up) and not up.startswith(code):
                        end_page = i
                        break
            if end_page is not None:
                break

        # Validation
        if start_page is None or not header_hit:
            return f"Section '{section_code} {section_title}' not found or missing table header."

        if end_page is None:
            end_page = len(pdf.pages)

        # Phase 2: layout-mode extraction on full range [start_page..end_page)
        collected = []
        in_table  = False

        for pi in range(start_page, end_page):
            layout = pdf.pages[pi].extract_text(layout=True) or ""
            for ln in layout.splitlines():
                up = ln.strip().upper()
                if not in_table:
                    if table_header_re.search(up):
                        in_table = True
                    continue
                # Stop at next section if it sneaks in layout text
                if next_sec_re.match(up) and not up.startswith(code):
                    break
                collected.append(ln)

        return "\n".join(collected).rstrip()

if __name__ == "__main__":
    pdf_file = "NC750XAP_13MKWM02_PC_2022_2023.pdf"
    print(extract_section_with_layout(
        pdf_file,
        section_code="F-50",
        section_title="MARK",
    ))
# Out:
#              Ref.
#       3      No. Part No.     Description     NC750XA NC750XD Serial No.         Parts catalogue code
#                                              M N  P M  N P
#               1 11378-MKS-E50 PLATE, EMBLEM∙∙∙∙∙∙∙∙∙∙∙∙∙∙∙∙ - - - 1 1 1
#               2 86201-MKA-A30ZB MARK, R. WING(105MM)
#                          *TYPE2*...................... 1 1 1 1 1 1
#                86201-MKW-D00ZC *TYPE1*...................... 1 1 - 1 1 - -------- --------2ED,CH,ED,FO,GS
#                86201-MKW-D00ZB *TYPE2*...................... 1 1 - 1 1 -
#                86201-MKW-D00ZA *TYPE3*...................... 1 - - 1 - - -------- --------2ED,ED
#                86201-MKW-D20ZB *TYPE2*...................... - - 1 - - 1 -------- --------2ED,ED
#                86201-MKW-D20ZC *TYPE1*...................... - - 1 - - 1
#                86201-MKW-D20ZA *TYPE3*...................... - - 1 - - 1 -------- --------2ED,ED,GS
#               3 86202-MKA-A30ZB MARK, L. WING(105MM)
#                          *TYPE2*...................... 1 1 1 1 1 1
#                86202-MKW-D00ZC *TYPE1*...................... 1 1 - 1 1 - -------- --------2ED,CH,ED,FO,GS
#                86202-MKW-D00ZB *TYPE2*...................... 1 1 - 1 1 -
#                86202-MKW-D00ZA *TYPE3*...................... 1 - - 1 - - -------- --------2ED,ED
#                86202-MKW-D20ZB *TYPE2*...................... - - 1 - - 1 -------- --------2ED,ED
#                86202-MKW-D20ZC *TYPE1*...................... - - 1 - - 1
#                86202-MKW-D20ZA *TYPE3*...................... - - 1 - - 1 -------- --------2ED,ED,GS
#               4 86611-MJF-A00ZA MARK, ABS
#                          *TYPE2*...................... 1 1 1 1 1 1
#                86611-MJF-A00ZB *TYPE1*...................... 1 1 1 1 1 1
#           148
#                                                     2022.08.01 E
#
#
#
#                                                    PART NO. INDEX
#
#
#                Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref.
#                 06000                  85 1 15150-MGS-D30 69 5 17513-MKW-D00 109 8 19080-MKW-D01 135 10 23231-MKT-D00 77 5
#                             12290-RSH-003 53 5 15154-MAT-000 69 6 17514-MKW-D00 109 9 19101-MGS-D30 135 11 23405-MKA-D50 62 6
#              06111-MJL-D30 85 1 12300-MKA-D30 52 1    86 1 17516-MEE-D00 109 10 19105-MR8-300 142 1 23406-MGS-D20 62 7
#              06112-MKT-D00 86 1 12300-MKA-D31 52 1 15410-MFJ-D02 69 7 17517-MGS-D30 109 11 19106-GET-000 135 12 23421-MKT-D00 78 2
#              06112-MKW-D00 86 1 12391-MGS-D30 52 2 15412-MGS-D21 59 6 17517-MKW-D00 109 12 19107-GET-000 135 13 23421-MKW-D00 75 4
#              06112-MKW-D10 86 1        85 1 15414-MEB-670 59 7 17518-MGS-D30 109 13 19126-KM1-010 116 12 23431-MKW-D00 75 5
#              06406-MKW-D00 122 1           15447-149-000 111 1 17518-MKW-D00 109 14 19200-MGS-D30 67 1 23441-MKT-D00 78 3
#              06406-MKW-D10 122 1 13000     15516-MGS-D30 65 4 17526-MKW-D01 109 15 19221-MGS-D30 67 2 23441-MKW-D00 75 6
#              06410-MGS-D30 107 1           15651-MKT-D00 59 8 17530-MKW-D00 116 10 19226-MGS-D30 67 3 23442-ML7-000 78 4
#              06431-MA3-405 101 1 13011-MKT-D00 72 1 15651-MKW-D00 58 2 17532-MGS-D31 116 11 85 1 23442-MM4-000 75 7
#              06435-MGS-D32 105 1 13101-MKT-D00 72 2       17550-MKW-H50 109 16 19231-MGS-D30 67 4 23442-MS2-610 77 6
#              06436-MCT-016 106 1 13111-122-000 64 1 16000 17572-MKT-D00 109 17 19300-MCJ-003 83 1 23451-MKT-D00 77 7
#              06451-443-405 105 2 13111-PWA-000 72 3       17573-MKT-D00 109 18 19305-KV3-010 83 2 23451-MKW-D00 75 8
#              06455-MGS-D32 101 2 13204-PWA-003 72 4 16211-MKT-D00 53 6 17620-KFR-841 109 19 85 1 23461-MKT-D00 78 5
#                             13210-RB0-000 72 5 16218-MGS-D30 53 7 17622-GB7-900 135 1 19310-MGS-D30 83 3 23461-MKW-D00 75 9
#                 11000       13211-PWA-003 72 6 16400-MKT-D01 84 1 17632-383-832 109 20 19316-MGS-D30 83 4 23471-MKT-D00 77 8
#                             13212-PWA-003 72 6 16402-MKT-D01 84 2 17640-MGS-D30 70 8 19322-MGS-D30 83 5 23481-MKT-D00 78 6
#              11000-MKW-D00 70 1 13213-PWA-003 72 6 16410-MKT-D01 84 3 17675-KVJ-G00 109 21 19504-KY1-003 83 6 23481-MKW-D00 75 10
#              11000-MKW-D10 70 1 13214-PWA-003 72 6 16450-MKT-D01 84 4 17676-KVJ-G00 109 22 19504-MGP-000 135 14 23482-MV9-670 75 11
#              11103-MGS-D31 70 2 13215-PWA-003 72 6 16451-MKR-D10 84 5     19505-MGS-D30 135 15      78 7
#              11207-MFL-000 70 3 13216-PWA-003 72 6 16472-MKT-D00 84 6 18000 19505-ML3-770 135 16 23491-MKT-D00 77 9
#              11207-MGS-D30 70 4 13217-PWA-003 72 6 16542-MEL-003 84 7     19506-MGS-D30 135 17 23491-MKW-D00 75 12
#              11210-MGS-D31 69 1 13218-PWA-003 72 6 16640-MKT-D01 84 8 18150-MKW-D01 117 1 19515-MKW-D00 135 18 23492-MGS-D30 75 13
#              11320-MKW-D00 65 1 13300-MKT-D00 72 7 16647-MKT-D00 84 9 18291-MGS-D31 85 1 19516-MJH-Y00ZA 136 19 23495-KY1-000 78 8
#              11330-MGS-D40 59 1 13313-MGS-D31 72 8 16700-MKW-D01 109 1 117 2             23501-MKT-D00 78 9
#              11330-MKW-D00 58 1 13314-MGS-D31 72 8 16730-MKT-D01 109 2 18293-MCA-A20 117 3 22000 23501-MKW-D00 75 14
#              11332-MGS-D20 59 2 13315-MGS-D31 72 8 16960-ME9-000 116 1 18310-MKA-D82 117 4 23511-MKT-D00 77 10
#              11333-MKT-D00 66 1 13316-MGS-D31 72 8        18310-MKW-D01 117 4 22100-MKT-D01 62 1 23511-MKW-D00 75 15
#              11337-MGS-D40 59 3 13317-MGS-D31 72 8 17000  18310-MKW-F61 117 4 22100-MKW-D02 61 1 23512-MGS-D20 77 11
#              11338-MGS-D20 63 1 13410-MKT-D00 72 9        18310-MKW-T51 117 4 22116-MKW-D00 61 2 23512-MV9-670 75 16
#              11339-MGS-D20 59 4 13420-MKT-D00 73 10 17210-MKT-D00 115 1 18316-HW1-671 111 3 22121-MKN-D11 61 3 23521-MKT-D00 78 10
#              11344-MB0-000 114 1 13481-MGS-D30 73 11 17220-MKT-D00 115 2 18316-KFT-620 94 1 22125-ML7-000 61 4 23521-MKW-D00 75 17
#              11351-MGS-D50 65 2 13491-MJL-D30 73 12 17222-MKT-D01 115 3 18319-MKA-T50 117 5 22210-MKN-305 61 5 23801-MJS-J20 78 11
#              11351-MJL-D30 65 2            17223-MKT-D01 115 4 18319-MKT-F01 117 6 22350-MKG-A31 61 6 23801-MKW-D00 75 18
#              11355-MGS-D30 65 3 14000      17224-MKT-D00 115 5 18342-MKA-D81 117 7 22361-MKN-D11 61 7
#              11355-MJL-D30 65 3            17227-GS3-000 111 2 18345-MBT-610 117 8 22401-MKN-D11 61 8 24000
#              11361-MGS-D20 63 2 14110-MKT-D00 55 2 17230-MKT-D00 115 6 18373-413-000 117 9 22402-K87-A31 61 9
#              11362-MGS-D20 63 3 14321-MGS-D30 57 1 17232-KYJ-900 115 7 18392-MK4-000 117 10 22425-MJP-G51 61 10 24211-MGS-D20 80 1
#              11363-MGS-D20 63 4 14401-MGS-D31 57 2 17233-MKT-D00 115 8 18422-MFJ-D10 117 11 22500-MKA-D51 62 2 24211-MGS-D30 79 1
#              11371-MGS-D20 63 5 14510-MKT-D00 57 3 17235-MKT-D00 115 9 18423-MGS-D30 117 12 22810-MKW-D00 58 3 24212-MGS-D30 79 2
#                        86 1 14530-MGS-D30 57 4 17236-MGS-D30 115 10       22814-PFL-003 77 1 24212-MKA-D50 80 2
#                                                                                                           4
#              11372-MGS-D20 63 6 14620-MKA-D30 55 3 17237-MGS-D30 115 11 19000 22814-RGC-003 77 2 24213-MGS-D20 80 3
#              11378-MKS-E50 148 1 14623-MBA-000 57 5 17238-MGS-D30 115 12  22815-MJE-D00 58 4 24213-MGS-D30 79 3
#              11520-MGS-D20 82 1 14630-MGS-D30 55 4 17241-MKT-D00 115 13 19010-MGS-D31 135 2 22821-MKW-D00 58 5 24214-MGS-D20 80 4
#              11521-MJL-D30 70 5 14711-MGS-D30 55 5 17247-303-000 133 1 19010-MGS-T51 135 2 22847-MKW-D00 61 11 24250-MKT-D00 79 4
#              11522-MJL-D30 70 6 14721-MGS-D30 55 6 17265-MKT-D00 115 14 19010-MJL-S61 135 2 22870-MKW-D01 89 1 80 5
#              11522-MJL-D31 70 6 14744-MKA-D30 55 7 17310-MKF-D41 116 2 19014-KEA-003 135 3 24261-283-000 75 19
#                        86 1 14744-PM3-000 55 8 17312-MKW-D00 116 3 19016-MGS-D31 135 4 23000        78 12
#              11523-MKT-D01 82 2 14751-MKH-D21 55 9 17359-419-670 109 3 19020-MGS-D31 135 5 24271-743-000 95 1
#                        86 1 14771-MKT-D00 55 10 17411-KVR-C00 116 4 19034-MB3-000 144 1 23103-MGS-D20 62 3 24310-MGS-D22 80 6
#                             14775-MGS-D30 55 11 17411-MGS-T50 116 5  145 1 23103-MKW-D00 61 12 24310-MJL-D30 79 5
#                 12000       14781-MA6-000 55 12 17412-MGS-T50 116 6 19045-MFF-A51 135 6 23104-MKT-D00 62 4 24315-HL4-000 80 7
#                                            17413-MKW-D00 116 7 19045-MGS-T51 135 6 23115-MW4-000 62 5 24315-MAS-E00 79 6
#              12200-MKW-D00 53 1 15000      17414-MKW-D00 116 8 19045-MJF-H11 135 6 23210-MKT-D00 77 3 24321-KT8-030 80 8
#              12204-MJH-305 53 2            17415-MKW-D00 116 9 19051-MGS-D30 135 7 23211-MKW-D00 75 1 24322-MGE-D01 80 9
#              12205-MGS-305 53 3 15010-MKR-305 69 2 17500-MKW-D00 109 4 19052-MGH-640 135 8 23212-MGS-D30 75 2 24322-MM4-000 80 10
#              12208-PR3-000 70 7 15100-MGS-D20 69 3 17506-MKT-D00 109 5 19055-KPC-871 135 9 77 4 24324-KA3-711 80 11
#              12209-MA6-003 55 1 15100-MGS-D30 69 4 17507-MKW-D00 109 6 19055-KPP-T01 135 9 23220-MKT-D00 78 1 24325-KA3-711 80 12
#              12251-MJH-Y01 53 4 15104-MGS-D20 59 5 17508-MKW-D00 109 7 19055-MJF-H11 135 9 23220-MKW-D00 75 3 24326-KBH-901 80 13
#                                                                                                         149
#                                                     2022.08.01 E
#
#
#
#                                                    PART NO. INDEX
#
#
#                Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref.
#              24328-MGS-D20 80 14 31200-MGS-D21 68 1 33741-MS6-921 127 5 37610-MKW-D11 88 4 40000 43310-MKW-D01 103 3
#              24329-KA3-740 80 15 31200-MJL-D21 68 1 33742-KVJ-912 127 5 37620-MKW-D01 88 5 43310-MKW-H51 103 3
#              24329-MGS-D20 80 16 31201-MEW-921 68 2 33742-MGS-R80 99 2 37700-K48-A01 70 11 40510-MGS-D30 122 2 43311-MKW-D00 94 3
#              24430-MGE-000 80 17 31202-MEW-921 68 3 33743-MGS-R80 99 3 37750-KPH-701 70 12 40531-MJF-A02 122 3 43312-MKW-D00 94 4
#              24430-MGS-D30 79 7 31203-MEW-921 68 4        37830-MFP-A51 84 10 40540-MGS-D31 122 4 43314-MGS-D81 103 4
#              24434-MGS-D20 80 18 31204-MEW-921 68 5 35000 37870-MGS-D31 83 8 40540-MJF-A02 122 4 43314-MKA-S82 103 4
#              24434-MGS-D30 79 8 31205-MEW-921 68 6        37880-KWW-C01 115 15 40543-MGS-D30 122 5 43352-568-003 101 7
#              24435-MGE-000 79 9 31206-MEW-921 68 7 35010-MKW-D00 96 2 37971-MKR-D31 89 5 40545-MGS-D31 122 3 105 14
#                        80 19 31207-KS5-901 68 8 35010-MKW-D01 96 2   91 3 40546-MGS-D30 122 6 43353-461-771 101 8
#              24435-MGS-D20 80 20 31208-MEW-921 68 9 35100-MKW-D01 96 3                             105 15
#              24435-MGS-D30 79 10 31209-MEW-921 68 10 35101-MKW-D01 96 4 38000 41000      43362-MGS-D71 106 6
#              24610-MGS-D20 80 21 31210-MEW-921 68 11 35105-MGH-H20 96 5                  43450-MKW-D11 95 3
#              24610-MGS-D30 79 11 31300-KVZ-631 82 6 35113-MJE-D00 96 6 38110-KZV-J02 130 6 41201-MGS-D30 107 2 43455-MKW-D10 95 4
#              24615-MGE-D01 82 3 31500-KPB-B23 129 1 35121-MJE-D02 96 7 38110-MEE-013 130 6 41201-MKW-D10 107 2 43456-MGS-D70 95 5
#              24616-MGS-D21 82 4 31500-KPB-B24 129 1 35135-MKW-D01 89 2 38221-SNA-A41 130 7 41641-HC5-000 64 7 43468-MGS-D31 103 5
#              24617-MGE-D01 82 5 31500-MGS-D32 129 1 35135-MKW-D02 89 2 38221-SNA-A51 130 8 43503-MER-D01 103 6
#              24651-MGS-D20 80 22 31500-MGS-T52 129 1 35135-MKW-D11 91 1 38221-SNA-A81 130 9 42000 43504-MB2-006 103 7
#              24651-MGS-D30 79 12 31500-MJF-H12 129 1 35135-MKW-D12 91 1 38235-TA0-A01 146 1 43510-MKW-D01 103 8
#              24652-HA0-000 79 13 31600-K1B-T01 130 1 35160-MGS-D31 130 4 38255-MKW-D00 130 10 42301-MGS-D31 107 3 43511-KV3-831 103 9
#                        80 23 31730-MAS-601 130 2 35200-MKW-D01 89 3 38255-MKW-D10 130 10 42311-MGS-D10 107 4 43512-MKW-D01 103 10
#              24655-MKT-D00 79 14           35200-MKW-D02 89 3 38301-KZZ-J01 130 11 42312-MGS-D10 107 5 43514-KS6-701 103 11
#                        81 24   32000       35200-MKW-D11 91 2 38301-MKJ-D01 130 12 42515-MGS-D80 107 6 43520-MB2-315 103 12
#              24705-MGS-D30 119 1           35200-MKW-D12 91 2 38306-KK4-000 130 13 42524-T5A-003 101 5 43530-MS8-006 103 13
#              24706-MK3-770 119 2 32100-MKW-D00 130 3 35200-MKW-H51 89 3 38501-MEL-003 130 14 105 5
#              24710-MGS-D30 119 3 32100-MKW-D10 130 3 35200-MKW-H52 89 3 38501-MKR-D11 130 15 42615-MGS-D30 107 7 44000
#              24724-MBW-D21 119 4 32100-MKW-H50 130 3 35200-MKW-H61 91 2 38506-KZZ-900 130 16 42620-MGS-D10 107 8
#              24781-KR3-770 119 5 32100-MKW-H60 130 3 35200-MKW-H62 91 2 38510-MKW-D01 105 3 42625-MGS-D30 107 9 44125-MN5-000 127 6
#                             32102-MKW-D00 129 2 35330-MCJ-751 89 4 38514-MGS-D80 103 1 42650-MKA-D81ZB 107 10 44301-MGS-D30 102 4
#                 28000       32150-MGS-D20 83 7 35340-MGS-D31 92 1 38514-MJF-C10 92 2 42704-MER-D00 102 1 44311-MGS-D10 102 5
#                             32153-MGS-D30 65 5        95 2 38515-MKA-D80 105 4      107 11 44515-MKA-D80ZB 102 6
#              28101-MGS-D30 64 2 32171-MGS-D20 59 9 35350-MKW-D01 119 6 38516-MGE-003 92 3 42705-MER-D00 102 1 44620-MGS-D10 102 7
#              28102-MEH-000 64 3 32172-MGS-D70 59 10 35357-MGS-D30 119 7 38516-MJN-A11 94 2 107 11 44650-MKA-D81ZB 102 8
#              28106-MGS-D30 64 4 32173-MGS-D70 59 11 35600-MFJ-D01 70 9 38517-MGE-003 92 4 42706-MER-D00 102 1 44711-MJL-D33 102 9
#              28110-MGS-D30 64 5 32410-MGS-D30 129 3 35700-MKW-D01 121 1 38517-MKA-D80 101 3 107 11 44711-MKW-D01 102 9
#              28125-MM9-014 64 6 32601-MKW-D00 129 4 35700-MKW-D11 121 1 38520-MKW-D01 101 4 42711-MJL-D34 107 12
#              28333-300-000 120 1           35701-MG9-950 130 5 38610-MKW-D11 63 8 42711-MKW-D01 107 12 45000
#              28660-RFH-013 63 7 33000      35850-MR5-007 129 5 38770-MKW-D02 131 17 42755-MKA-D81 102 2
#                                            35856-KBG-007 129 6 38770-MKW-D13 131 17 107 13 45107-ML4-006 101 9
#                 30000       33100-MKW-D01 87 1            38770-MKW-E02 131 17 42758-MKA-D81 102 3 45111-MA3-006 105 16
#                             33111-MGH-640 87 2 36000      38770-MKW-E13 131 17      107 14 45111-MAJ-G41 101 10
#              30430-MKW-306 96 1 33113-K07-M51 127 1       38770-MKW-F63 131 17                     105 17
#       4
#              30430-MKW-315 96 1 33113-MEE-D01 87 3 36162-MKA-D81 116 13 38770-MKW-G02 130 17 43000 45111-MCT-006 106 7
#              30430-MKW-F61 96 1 33400-MKW-D01 126 1 36533-MKW-D01 117 13 38770-MKW-H52 131 17 45112-MS9-611 101 11
#              30430-MKW-G01 96 1 33400-MKW-H51 126 1       38770-MKW-H63 131 17 43107-KT7-761 105 6 45125-MKW-D01 92 5
#              30430-MKW-G02 96 1 33411-MKH-D00 126 2 37000 38770-MKW-K02 131 17 43108-MBB-006 105 7 45125-MKW-H51 92 5
#              30430-MKW-K01 96 1 33412-MKH-D00 126 3       38770-MKW-T52 131 17 43108-MCT-006 101 6 45126-MKW-D00 94 5
#              30433-MKA-D81 97 28 33450-MKW-D01 126 4 37100-MKW-D01 88 1 38770-MKW-T63 131 17 43110-MKA-D51 105 8 45127-MKW-D00 94 6
#              30511-MKW-D01 132 1 33450-MKW-H51 126 4 37100-MKW-D11 88 1 38780-MKW-D13 131 18 43110-MKA-D81 105 9 45128-MKL-K31 92 6
#              30512-MKW-D01 132 2 33452-MKH-D00 126 5 37100-MKW-T51 88 1 38780-MKW-E13 131 18 43112-MFF-D01 105 10 45128-MKL-S82 92 6
#              30520-ML7-000 132 3 33600-MKW-D01 126 6 37100-MKW-T61 88 1 38780-MKW-F63 131 18 43132-KT7-761 105 11 45131-MN9-006 105 18
#              30700-MGS-D31 132 4 33600-MKW-H51 126 6 37110-MKW-D01 88 2 38780-MKW-H63 131 18 43150-MKA-D51 105 12 45132-166-016 101 12
#                             33650-MKW-D01 126 7 37110-MKW-D11 88 2 38780-MKW-T63 131 18 43150-MKA-D81 105 12 106 8
#                 31000       33650-MKW-H51 126 7 37110-MKW-T51 88 2 38800-MKW-D01 70 13 43160-MKW-D10 103 2 45133-166-016 106 9
#                             33701-MKV-D03 127 2 37110-MKW-T61 88 2 38800-MKW-D11 82 7 43208-MCT-006 106 2 45133-MA3-006 101 13
#              31110-MKT-D01 66 2 33705-MKK-D00 127 3 37241-RNA-A01 70 10 38810-MKW-D11 59 12 43215-KZ4-J41 105 13 105 19
#              31110-MKW-D01 66 2 33720-MKW-D01 127 4 37244-MM4-000 88 3 38815-MGS-D20 82 8 43215-MCT-006 106 3 45155-MGS-D80 92 7
#              31120-MKW-D01 66 3 33720-MKW-H51 127 4 37500-MKT-D01 65 6 38815-MJL-D10 70 14 43250-MKA-D51 106 4 45156-MJL-D80 92 8
#              31120-MKW-D11 66 3 33740-MKA-D81 133 2 37511-MKT-D00 65 7    43251-MGS-D31 107 15 45160-MJF-C11 92 9
#              31125-MKT-D00 66 4 33741-KSH-902 99 1 37610-MKW-D01 88 4     43290-MKA-D51 106 5 45215-MAJ-G41 101 14
#           150
#                                                     2022.08.01 E
#
#
#
#                                                    PART NO. INDEX
#
#
#                Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref.
#              45250-MKA-D81 101 15 50608-KV0-000 117 15 53000 64141-MKW-D00 139 2 75000   81325-MKW-D00 141 7
#              45251-MGS-D81 102 10 50609-MBW-000 120 2     64151-MKW-D00ZA 142 4          81331-MKW-D00 139 7
#              45290-MKA-D81 101 16 50617-445-840 120 3 53100-MKW-D00ZA 96 8 64151-MKW-D00ZC 142 4 75581-MGP-D60 139 4 81335-MKA-N60 139 8
#              45504-410-003 92 10 50631-MGS-D30 120 4 53105-KV3-000 96 9 64161-MKW-D00ZA 142 5 81340-MKW-D00 141 8
#              45510-MGS-D31 92 11 50635-MGS-D30 120 5 53105-MK4-620 96 10 64161-MKW-D00ZC 142 5 77000 81342-MKW-D00 141 9
#              45512-MA6-006 92 12 50636-MGS-D30 120 6 53106-KR3-000 96 11 64181-MKW-D00 137 3 81360-MKW-D00 141 10
#              45513-KK1-771 103 14 50639-MFL-D20 120 7 53107-MY1-000 96 12 64201-MKW-D00 137 4 77100-MKW-D01ZA 111 7 81362-MKW-D00 141 11
#              45513-MM5-016 92 13 50644-445-840 120 8 53108-KR3-770 96 13 64205-166-610 137 5 77113-MKT-D00 138 4
#              45517-166-006 89 6 50650-MKW-D00ZA 120 9 53111-MKW-D00 96 14 64209-MN5-000 65 8 77206-GF0-000 111 8 82000
#                        92 14 50661-MBW-000 120 10 53111-MKW-D10 96 14 64224-MKW-D00 137 6 133 19
#              45518-MM5-006 92 15 50711-MGS-D30 120 11 53125-174-670 59 13 64228-MGH-640 142 6 77211-MKW-D00 113 1 82140-MKW-D01 141 12
#              45520-MG7-006 103 15 50712-MGS-D30 120 12 127 7 64234-MKW-D00 137 7 77212-MFJ-D00 127 8
#              45520-MM5-006 92 16 50715-KE8-000 119 10 142 2 64242-MKW-D00 144 2 77220-MGS-D31 111 9 83000
#              45521-HA2-006 103 16 50718-MN8-000 120 13 53130-MGS-D30ZA 96 15 145 3 77221-MKW-D00ZA 113 2
#              45530-KVY-911 92 17 50750-MKW-D00ZA 120 14 53140-MKK-D01 89 7 64300-MGS-D30ZA 144 3 77221-MKW-D00ZC 113 2 83511-MKW-D00 114 4
#                                                       91 4 64300-MGS-D51ZA 145 4 77223-MW3-670 114 3 83520-MKW-D00ZA 139 9
#                 46000          51000       53166-MGE-000 89 8 64330-MKW-D00ZA 142 7 77231-MKW-D00ZA 113 3 83520-MKW-D00ZB 139 9
#                                                       91 5 64330-MKW-D00ZB 142 7 77231-MKW-D00ZC 113 3 83520-MKW-D00ZC 139 9
#              46182-MEL-D21 103 17 51400-MKW-D01 100 1 53170-MKK-D01 92 18 64330-MKW-D00ZC 142 7 77234-KYZ-900 141 2 83520-MKW-D00ZD 139 9
#              46184-611-000 106 10 51401-MKW-D01 100 2 53172-MKW-D00 89 9 64330-MKW-D00ZD 142 7 77236-KEA-000 146 2 83520-MKW-D20ZA 139 9
#              46500-MKW-D00 119 8 51402-MGZ-J01 100 3 53178-MJE-D00 89 10 64330-MKW-D20ZA 142 7 77239-MKA-D82 139 5 83520-MKW-D20ZB 139 9
#              46504-MT8-006 103 18 51410-MKL-D81 100 4 53192-349-690 89 11 64330-MKW-D20ZB 142 7 77239-MKA-D83 139 5 83520-MKW-D20ZC 139 9
#              46511-MV9-000 119 9 51412-MB4-003 100 5 53213-MB4-771 98 1 64330-MKW-D20ZC 142 7 77241-MKW-D01 111 10 83531-MKW-D00ZA 114 5
#                             51414-MFJ-A51 100 6 53214-371-010 98 2 64340-MKW-D00ZA 142 8 77242-MGS-D30 111 11 83545-KCJ-690 115 16
#                 47000       51415-MFJ-A51 100 7 53219-MGS-D30 98 3 64340-MKW-D00ZB 142 8 77250-MGS-D30 111 12 83551-GE2-000 120 15
#                             51416-MKL-D81 100 8 53220-422-000 98 4 64340-MKW-D00ZC 142 8 77251-GR1-000 146 3 125 2
#              47111-MKW-D10 95 6 51420-MGS-D31 100 9 53230-MGS-D30 97 16 64340-MKW-D00ZD 142 8 77251-MGS-D30 111 13 133 20
#              47117-MGS-D50 95 7 51432-MV4-003 100 10 53232-MJ4-670 97 17 64340-MKW-D20ZA 142 8 77255-MKW-D00 111 14 137 8
#              47152-MGS-D51 95 8 51437-MKL-D81 100 11 53781-SE0-952 131 20 64340-MKW-D20ZB 142 8 77261-MKW-D00 113 4 139 10
#              47154-MGE-D00 95 9 51440-MKW-D01 100 12      64340-MKW-D20ZC 142 8 77271-MKW-D00 113 5 141 13
#              47155-MGE-D00 95 10 51447-KA4-711 100 13 57000 64351-MKW-D00ZA 143 9 77300-MKW-D01ZA 111 15 143 13
#              47156-MGE-D00 95 11 51454-MKL-D81 100 14     64351-MKW-D00ZC 143 9 77302-MEE-000 111 16 144 10
#              47200-MKW-D10 95 12 51490-MKL-D81 100 15 57110-MKW-D01 94 7 64361-MKW-D00ZA 143 10 77320-MGS-D31 111 17 145 9
#              47210-MGS-D51 95 13 51500-MKW-D01 100 16     64361-MKW-D00ZC 143 10 77330-MJJ-D10 113 6 83606-KWS-901 133 21
#                             51520-MGS-D31 100 17 60000    64371-MKW-D00 143 11 77340-MJJ-D10 113 7 83611-MKW-D00 114 6
#                 50000                                     64381-MKW-D00 143 12           83620-MKW-D00ZA 139 11
#                                52000       60107-752-000 114 2 64400-MGS-D31ZA 144 4 80000 83620-MKW-D00ZB 139 11
#              50010-MKW-D00ZA 133 3                        64400-MGS-D51ZA 145 5          83620-MKW-D00ZC 139 11
#              50100-MKW-D00ZA 133 4 52101-MGS-D30 122 7 61000 64500-MKW-D00ZA 144 5 80100-MKA-D80 127 9 83620-MKW-D00ZD 139 11
#              50191-MGS-D10 133 5 52141-MGS-D10 122 8                 145 6 80100-MKA-S80 127 9 83620-MKW-D20ZA 139 11
#              50192-MGS-D10 133 6 52142-MGS-D10 122 9 61000-MJL-D80ZE 99 4 64520-MGS-D50ZA 59 14 80101-165-000 99 9 83620-MKW-D20ZB 139 11
#                                                                                                           4
#              50193-MGS-D10 133 7 52143-KZ3-860 61 13 61000-MKA-D81ZD 99 4 64528-KV3-000 139 3 139 6 83620-MKW-D20ZC 139 11
#              50194-MKT-D00 133 8 52143-MGS-D10 122 10 61101-MGS-D30 99 5 64541-MGS-D30 144 6 80101-283-000 127 10 83631-MKW-D00ZA 114 7
#              50195-MKT-D00 133 9 52170-MGS-D30 122 11 61102-MGS-D30 99 6 145 7 80101-310-000 127 11 83705-MZ7-300 110 23
#              50196-MKW-D00 133 10 52171-KR6-000 122 12 61103-MGS-D30 99 7 64542-MGS-D30 144 7 80101-MKW-D00 127 12
#              50197-MGS-D50 133 11 52200-MGS-D32 122 13 61103-MJP-G50 87 4 64542-MGS-D50 145 8 80103-MCJ-750 59 15 84000
#              50230-MKW-D00 133 12 52200-MGS-D71 122 13 61104-435-000 111 5 64543-MKW-D00 144 8 80104-KJ2-000 127 13
#              50234-MKW-D00 133 13 52400-MKW-D01 124 1 61104-MGS-D30 99 8 64544-MKW-D00 144 9 80105-MKW-D00 125 1 84706-163-670 99 10
#              50236-MKW-D00 133 14 52400-MKW-H51 124 1 61112-727-000 145 2 64800-MKW-D00 138 1 80106-MKW-D00 127 14
#              50237-MKW-D00 133 15 52400-MKW-K01 124 1 61304-415-000 111 6 64816-MKW-D00 138 2 80116-MKW-D00 127 15 86000
#              50238-MKW-D00 133 16 52400-MKW-T51 124 1 61304-HB3-003 133 18 64821-MKW-D00ZA 138 3
#              50239-MGS-D30 133 17 52462-MGS-D10 124 2 61310-MKW-D00 137 1 64821-MKW-D00ZB 138 3 81000 86150-KPG-901 97 18
#              50290-MZ7-000 141 1 52463-MAL-G00 124 3 61310-MKW-D01 137 1 64821-MKW-D00ZC 138 3 86150-KPG-902 97 18
#              50311-MGS-D31 131 19 52463-MGS-D10 122 14    64821-MKW-D00ZD 138 3 81112-MCA-S40 141 3 86201-MKA-A30ZB 148 2
#              50318-041-600 139 1      124 4   64000       64821-MKW-D00ZG 138 3 81210-MKW-D00 129 7 86201-MKW-D00ZA 148 2
#              50354-428-000 111 4 52465-MGS-D30 124 5      64821-MKW-D00ZH 138 3 81251-MKW-D00 141 4 86201-MKW-D00ZB 148 2
#              50530-MKW-D00 121 2 52471-MGS-D30 124 6 64111-MKW-D00 137 2 64821-MKW-D00ZJ 138 3 81280-MGS-D30 138 5 86201-MKW-D00ZC 148 2
#              50540-MFL-000 121 3           64121-MER-D00 127 8            81310-MKW-D00 141 5 86201-MKW-D20ZA 148 2
#              50607-KK6-000 117 14          64131-MKW-D00 142 3            81315-MKW-D00 141 6 86201-MKW-D20ZB 148 2
#                                                                                                         151
#                                                     2022.08.01 E
#
#
#
#                                                    PART NO. INDEX
#
#
#                Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref.
#              86201-MKW-D20ZC 148 2 90000   90037-422-003 75 20 90116-K0A-E11 140 14 90303-HA0-680 125 6 90488-425-000 57 8
#              86202-MKA-A30ZB 148 3                    78 13 90116-KV3-701 100 19    141 22          58 8
#              86202-MKW-D00ZA 148 3 90001-MGS-D20 70 15 90048-MGS-D30 55 14 90116-MKS-E20 117 19 90303-MBZ-G00 123 17 59 22
#              86202-MKW-D00ZB 148 3     82 9 90050-MKZ-J01 61 15 90116-SP0-003 113 9 90304-GE8-003 124 12 85 1
#              86202-MKW-D00ZC 148 3 90001-MZ8-U40 57 6 90062-RGH-A00 110 24 114 9 90304-MCF-000 97 24 86 1
#              86202-MKW-D20ZA 148 3 90002-MGS-D20 82 10 90071-MB0-000 68 12 125 4 90304-ME1-670 117 20 90493-MGE-D00 77 16
#              86202-MKW-D20ZB 148 3 90002-RGA-000 70 16 90084-MN8-010 65 15 140 15 90305-GEE-710 125 7 90501-819-000 117 21
#              86202-MKW-D20ZC 148 3 90003-MGS-D20 82 11 90085-KFB-000 125 3 141 19 90306-MCS-G01 107 19 90501-MFA-D00 111 19
#              86611-MJF-A00ZA 148 4 90003-MW3-620 89 15 131 21        143 15         123 18 90501-MKW-D10 145 13
#              86611-MJF-A00ZB 148 4     91 9 90085-MCZ-000 59 21 90117-MJK-N20 140 16 90313-HE0-006 106 13 90504-964-000 137 12
#                             90004-MGS-D30 70 17 90087-MGS-D30 53 11 90117-MJP-G60 101 18 90315-MFL-003 136 22 90505-MC4-000 127 17
#                 87000       90006-GHB-690 67 5 90087-MR1-000 65 16   105 21 90321-KT7-760 90 21 90506-425-830 98 7
#                             90006-GHB-700 67 6 90101-MAS-000 111 18 90118-MBW-000 120 17 90364-MEJ-000 134 26 90507-ZV1-000 137 13
#              87125-MKA-DJ0 147 1 90006-GHB-730 67 7 90101-MBB-000 124 8 90118-MEL-000 99 12 90401-430-000 95 14 90508-MGE-D00 90 22
#              87505-MJE-T20 147 2 90006-PWC-003 55 13 90101-MGS-D70 106 11 90118-MJK-N20 122 15 90401-MAS-000 108 20 91 11
#              87505-MKA-DG0 147 3 90007-MGS-D31 53 8 90101-MJJ-D30 139 12 125 5      123 19 90514-921-000 119 15
#              87505-MKA-HH0 147 2 90008-ZM7-000 127 16 141 14         141 20 90402-MEW-920 75 21 90515-046-810 95 15
#              87505-MKA-SJ0 147 2 90010-MAY-000 64 8 90101-MKA-T50 117 16 90120-GHB-601 136 21 90403-MEW-920 66 6 90534-MV4-000 117 22
#              87508-MJJ-D31 147 4 90010-ML0-720 119 11 90102-MAS-000 107 16 90120-MJK-N20 138 7 90403-MGS-D20 62 9 90543-MV9-670 52 4
#              87509-MGE-680 147 5 90011-MGE-D00 59 16 90102-MGS-D30 124 9 141 21 90403-MK2-300 77 12 85 1
#              87512-MGS-D30 147 6       70 18 90102-MKA-D80 103 20    143 16 90404-680-000 110 25 90544-283-000 100 20
#              87516-KFK-750 124 7       82 12         144 11          144 12 90406-MGS-D30 67 8 90545-300-000 93 25
#              87516-MCA-G60 124 7 90013-GHB-610 101 17 145 10         145 12         85  1          104 22
#              87516-MGS-T70 124 7      105 20 90102-MN8-700 134 22 90122-MJK-N20 129 10 90414-MKT-D00 61 17 90545-KF0-000 71 28
#              87516-MJF-H10 124 7 90013-GHB-620 92 19 90103-KCM-620 117 17 137 10    62 10           86 1
#              87520-MEW-D40 147 7 90013-GHB-660 89 16 90103-MGS-D30 134 23 140 17 90417-360-000 79 15 90559-MKW-D00 108 21
#              87520-MGS-H80 147 8       92 20 90103-MGS-D50 140 13    143 17 90432-MM5-000 61 18 90601-107-000 76 32
#              87560-KVB-900 147 9 90013-GHB-670 92 21 141 15          144 13 90433-KE1-000 81 25 90601-KAF-003 119 16
#              87560-MBR-871 147 10 90013-GHB-700 103 19 145 11 90123-MKH-D00 126 8 90442-028-000 71 24 90603-MN4-000 76 33
#              87560-MGE-680 147 11 90015-MGS-D31 70 19 90103-MKW-D00 140 13 90124-MCJ-752 89 18 86 1 78 20
#              87560-MKJ-D00 147 12 90016-MFA-D01 70 20 141 15 90128-MGS-D30 131 22 90443-MB0-000 71 25 90604-MM5-000 77 17
#              87562-MGE-680 147 13 90017-MGS-D30 52 3 145 11 90131-883-000 69 10     86  1 90605-MGE-D00 77 18
#              87586-MGC-DD0 147 14 90019-MB0-000 69 8 90104-MGS-D30 134 24 90131-KBV-003 101 19 90443-MJ6-000 71 26 90650-KV6-003 90 23
#              87593-MKA-S80 147 15 90020-MBW-610 97 19 90105-MBB-000 107 17 90133-MJE-D00 143 18 86 1 91 12
#              87700-KVG-901 147 16 90021-MGS-D30 70 21 90105-MGS-D30 102 11 90134-MJE-D00 137 11 90451-704-000 75 22 121 7
#                             90021-MJL-D30 71 22 90106-KBV-000 113 8  143 19 90451-KY2-000 75 23 90651-HL3-G01 110 26
#                 88000       90022-MJL-D30 71 23 90106-MAV-000 141 16 90145-MS9-612 93 23 90452-KZ4-000 78 14 90651-K14-A31 113 10
#                             90023-GHB-720 53 9 90106-MFF-D00 99 11   104 21 90452-MAT-000 77 13    143 20
#              88130-MFG-D00 89 12 90023-MBW-000 61 14 90106-MM9-000 134 25 90147-MCE-950 121 5 90452-MKP-D01 61 19 90651-KV6-003 90 24
#                        91 6            62 8 90107-KTW-900 129 8 90160-MGJ-D00 97 22 90452-MR7-000 76 24 95 16
#              88210-MKS-E00 89 13 90023-MGS-D30 53 10 90107-MBG-000 97 20 90165-MGS-D30 119 13 78 15 90651-MA5-671 93 26
#       4
#                        91 7 90025-MEW-920 66 5 90108-MK6-670 121 4 90166-GHB-700 98 5 90453-235-000 79 16 90651-MEW-920 123 20
#              88210-MKS-HB0 89 13 90026-GHB-650 65 9 90109-MR7-000 100 18 90175-MCT-640 94 8 90456-MA6-000 76 25 90652-HC4-003 90 25
#                        91 7 90026-GHB-670 65 10 90110-MGS-D30 124 10 90180-MGS-D71 106 12 90458-292-000 78 16 91 13
#              88220-MKS-E00 89 14 90028-GHB-640 59 17 90111-162-000 136 20 90180-MN8-006 105 22 90458-MAT-E00 77 14 131 23
#                        91 8 90028-GHB-670 83 9 90111-362-000 97 21 90191-KBG-000 97 23 90459-438-000 76 26 90652-KSJ-A21 116 14
#              88220-MKS-HB0 89 14 90028-GHB-680 65 11 90111-KW3-003 137 9 90201-415-000 90 19 78 17 90654-SA4-003 129 11
#                        91 8 90028-GHB-690 58 6       141 17          93 24 90461-MW0-000 76 27     141 23
#                                        59 18         143 14 90201-KV3-700 119 14 90462-MBW-000 76 28 90656-MGH-641 120 18
#                 89000                  65 12 90111-MGS-D30 124 11 90201-MW3-620 90 20 90463-MKT-D00 77 15 90661-MCA-003 94 9
#                                        69 9 90111-MR5-000 129 9      91 10 90463-ML7-000 67 8 90661-MGS-D81 94 10
#              89101-MC7-000 146 4 90028-GHB-740 58 7 90112-MBR-J10 120 16 90203-MF9-710 121 6 71 27 90677-KAN-961 87 5
#              89102-538-000 146 5       59 19 90112-MKA-D80 138 6 90206-MKA-D30 55 15 85 1          129 12
#              89103-538-000 146 6       65 13 90113-438-000 89 17 90206-PM3-004 55 16 86 1          134 27
#              89216-KB7-000 146 7 90028-GHB-750 65 14 90113-GFP-B00 117 18 90231-MM5-000 61 16 90463-MR7-000 76 29 137 14
#              89216-MGS-D30 146 8 90028-GHB-760 59 20 90113-HP6-A00 114 8 90301-473-003 99 13 78 18 141 24
#              89221-429-000 146 9       84 11 90114-MA5-671 92 22 90302-425-830 98 6 90464-MR7-000 76 30 143 21
#              89230-MB1-000 146 10 90028-GHB-770 83 10 90114-MFL-000 141 18 90302-MBZ-G00 122 16 78 19 90683-MBW-003 114 10
#              89256-MT4-000 146 11 90031-PV0-003 57 7 90115-KAF-000 119 12 90302-MKT-D01 107 18 90469-ME5-000 76 31 90683-MGC-920 118 23
#           152
#                                                     2022.08.01 E
#
#
#
#                                                    PART NO. INDEX
#
#
#                Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref. Part Number Page Ref.
#              90683-MGC-920 136 23 91262-KV3-831 124 15 91535-STK-003 131 28 131 33 95701-06012-08 116 18 96100-63040-00 73 16
#              90690-GHB-631 131 24 91301-MEE-003 69 11 91535-TA0-003 131 29 94050-08000 114 12 134 32 96211-08000 120 22
#              90690-GHB-641 95 17       86 1 91558-SD5-003 131 30 94050-08070 134 29 95701-06014-00 57 9 96220-40080 79 22
#                        132 5 91301-MEH-003 63 9 91565-SEL-003 90 28 94050-08080 118 24 71 34        81 33
#              90690-GHB-651 90 26       86 1           91 16 94050-12000 134 30      73 14 96300-08045-04 118 25
#                        91 14 91301-MGS-D30 67 10     131 31 94101-04800 112 23      76 40 96300-08050-04 118 26
#                        131 25          85 1 91771-MKG-D81 131 32 94101-05000 140 19 77 22 96600-06016-08 97 27
#              90690-GHB-671 131 26 91301-MKP-T01 84 12     94101-08700 134 31        79 20 96600-06020-07 95 25
#              90690-MGS-D81 105 23 91302-MGS-D20 60 24 92000 94101-08800 113 13      81 30 96600-08020-10 79 23
#              90701-MV9-670 71 29       86 1               94102-08000 120 20 95701-06014-02 136 29 96700-08025-00 113 14
#              90703-PWA-003 55 17 91302-PA9-003 60 25 92101-06022-4J 132 6 138 8 95701-06014-07 104 29
#              90704-MGS-D30 67 9        86 1 92501-06016-0A 120 19 94103-04700 128 22 95701-06014-08 60 34 98000
#              90741-413-000 73 13 91302-PS5-003 62 11      94103-05700 88 8          131 34
#              90801-SB0-000 95 18       86 1   93000       94103-05800 112 24        136 30 98200-33000 129 17
#              90899-MB2-000 127 18 91303-377-000 65 17     94103-06800 128 23        144 14
#                                        86 1 93401-06012-08 137 15 94103-08800 112 25 145 14 99000
#                 91000       91303-KK3-830 53 12 93404-06020-08 94 11 128 23 95701-06016-00 60 35
#                                        85 1          115 17 94109-12000 69 13       63 11 99001-08120 146 12
#              91001-MGS-D31 76 34 91303-MKH-D21 71 30 93404-06025-00 111 20 86 1 95701-06018-00 71 35 99001-10140 146 13
#              91006-MGS-D31 76 35       86 1 93404-06025-08 87 6 94201-16180 138 9 95701-06018-08 131 35 99006-12000 146 14
#                        77 19 91306-ZY3-003 67 11 93404-10025-08 137 16 94201-20150 104 27 136 31 99006-22000 146 15
#              91007-MGS-D21 79 17       85 1 93500-04025-0G 115 18    120 21 95701-06020-08 132 7 99006-27000 146 16
#                        81 26 91307-035-000 58 11 93500-05012-0H 140 18 94251-05000 112 26 95701-06022-00 104 30 99008-02000 146 4
#              91008-MGS-D31 64 9        60 26 93500-05016-0G 95 19 94301-08100 63 10 95701-06025-00 63 12
#              91015-KT8-005 98 8        86 1 93600-04012-1G 93 27     71 32 95701-06025-08 136 32
#              91016-KT8-005 98 9 91307-PY4-003 69 12 93600-04040-1G 104 24 82 18 95701-06035-00 81 31
#              91022-MJE-DB1 76 36       86 1 93892-04008-18 90 29 94301-08140 58 12 95701-06040-08 110 28
#                        78 21 91309-425-003 68 13      91 17          65 21 95701-06045-00 63 13
#              91023-MGS-D21 77 20       86 1 93892-04014-07 95 20     69 14 95701-06045-08 79 21
#              91025-MGS-D21 82 13 91310-MGE-D01 60 27 93892-05010-08 90 30 94301-08200 60 32 95701-06055-00 63 14
#              91026-MEL-003 76 37       71 31          91 18          81 28          69 15
#              91026-MGS-D21 82 14       82 16         116 15 94301-12200 53 13       81 32
#              91027-MGS-D21 82 15       86 1 93892-05012-08 68 15 94303-05080 55 18 95701-06075-00 69 16
#              91029-MGS-D21 60 23 91311-RFH-003 60 28 93892-06014-18 84 13 94305-30223 95 21 95701-08018-08 137 18
#              91051-MGS-D31 108 22      86 1 93893-04008-07 136 24 94305-30283 95 22 144 15
#              91052-MGS-D31 123 21 91313-393-003 65 18 93893-04012-17 93 28 94510-14000 81 29 145 15
#                        124 13          86 1          104 25 94510-16000 79 19 95701-08020-07 134 33
#              91053-MFJ-D01 58 9 91315-MGS-D20 60 29 93901-22180 136 25 94511-19000 119 18 95701-08022-08 134 34
#              91053-MGS-D31 102 12 91320-MB0-000 68 14 93901-22320 143 23 94520-40150 60 33 144 16
#                        108 23 91333-PNC-006 65 19 93901-25280 123 27 94540-09018 95 23 95701-08025-08 131 36
#              91054-MGS-D31 123 22      86 1 93903-224J0 88 6 94560-62200 76 39 95701-08045-00 71 36
#                                                                                                           4
#              91055-MGS-D31 123 23 91344-PC9-004 60 30 93903-24310 137 17 78 23 95701-08070-00 71 37
#              91059-KY2-711 97 25       65 20 93903-24480 127 19           95701-10070-00 71 38
#              91071-KV3-005 124 14      86 1 93903-25280 127 20 95000      95701-12035-08 134 35
#              91071-MR7-003 123 24 91351-HM8-A51 82 17 93903-25580 115 19  95701-12045-08 134 36
#              91104-PL9-008 77 21       86 1 93913-14220 111 21 95002-02100 136 26 95701-12055-08 134 37
#              91201-MGS-D31 79 18 91351-MGS-D30 108 26 93913-25380 88 7 95002-40730-08 116 16 95701-12080-08 134 38
#              91202-MR7-003 123 25 91356-425-003 83 11 93913-255J0 115 20 95002-50000 129 13 95801-06025-00 68 16
#              91203-KK3-830 81 27       85 1               95003-23019-60 115 21
#              91204-KK0-003 58 10 91356-KF0-003 100 22 94000 95005-35080-20 84 14 96000
#              91207-KT8-003 76 38 91456-MCW-D01 113 11     95005-45340-20 116 17
#                        78 22 91475-SB6-000 143 22 94002-06020-0S 119 17 95005-45380-20 116 17 96001-06014-00 60 36
#              91208-PF5-005 106 14 91501-MGS-D30 113 12 94002-08000-0S 104 26 95005-50290-30 129 14 66 7
#              91212-422-006 104 23     134 28 94002-08070-0S 90 31 95005-55250-20 136 27 95 24
#              91251-MGS-D31 108 24 91501-MKA-D80 97 26 94021-08020-0S 114 11 95005-55580-20 136 28 104 31
#              91251-MKL-D81 100 21 91502-MGS-D50 60 31 94031-08070 90 32 95012-17001 129 15 96001-06022-07 99 14
#              91252-MC4-013 102 13 91533-MGS-D30 90 27 94050-05080 128 21 95015-54000 104 28 96001-06040-00 66 8
#              91253-KZ3-861 123 26      91 15 94050-06080 110 27 95701-06010-08 129 16 96001-06045-00 66 8
#              91253-MAE-003 108 25     131 27         111 22 95701-06012-00 71 33 96100-62040-00 73 15
#                                                                                                         153
#                                                     2022.08.01 E
#
#
#
#                                                   PART NAME  INDEX
#
#
#                     Part name      Page Ref.       Part name     Page  Ref.      Part name      Page Ref.
#                     [ A ]                  BEARING, NEEDLE, 17X24X30 •••• 123 21 BOLT, FLANGE, 12X168•••••••••• 134 24
#                                                                   124  13 BOLT, FLANGE, 12X276•••••••••• 134 23
#              ADJUSTER, CHAIN••••••••••••••• 122 5 BEARING, NEEDLE, 20MM •••••••• 76 36 BOLT, FLANGE, 12X35••••••••••• 134 35
#              ARM••••••••••••••••••••••••••• 106 6                 78   21 BOLT, FLANGE, 12X45••••••••••• 134 36
#              ARM ASSY., ROCKER••••••••••••• 55 3 BEARING, NEEDLE, 24X28X10 •••• 76 37 BOLT, FLANGE, 12X50••••••••••• 66 5
#              ARM COMP., CHANGE••••••••••••• 119 3 BEARING, NEEDLE, 26X31X22 •••• 77 21 BOLT, FLANGE, 12X55••••••••••• 134 37
#              ARM SUB ASSY., CUSHION•••••••• 124 5 BEARING, NEEDLE, 30X37X20 •••• 64 9 BOLT, FLANGE, 12X80••••••••••• 134 38
#              ARM, L. MAIN STEP••••••••••••• 120 6                 123  23 BOLT, FLANGE, 6MM••••••••••••• 136 20
#              ARM, L. PILLION STEP•••••••••• 120 12 BEARING, RADIAL BALL,  BOLT, FLANGE, 6X10•••••••••••• 129 16
#              ARM, R. MAIN STEP••••••••••••• 120 5       40X68X7.5 60   23 BOLT, FLANGE, 6X12•••••••••••• 71 33
#              ARM, R. PILLION STEP•••••••••• 120 11 BEARING, RADIAL BALL, 20X37X9 123 22         101  17
#              ARM, SEAT HINGE••••••••••••••• 111 14 BEARING, RADIAL BALL, 25X47X8 79 17          105  20
#              AXLE, FR. WHEEL••••••••••••••• 102 4                 81   26                       116  18
#              AXLE, RR. WHEEL••••••••••••••• 107 3 BEARING, RADIAL BALL, 31X68X15 76 34          134  32
#                                            BEARING, RADIAL BALL, 6008 ••• 77 20 BOLT, FLANGE, 6X14•••••••••••• 57 9
#                     [ B ]                  BEARING, RADIAL BALL, 607ZZ •• 82 14                  60  34
#                                            BEARING, RADIAL BALL, 6204 ••• 73 15                      36
#              BAG, SERVICE BOOK••••••••••••• 146 3 BEARING, RADIAL BALL, 6204U •• 76 35           66   7
#              BAG, TOOL••••••••••••••••••••• 146 4                 77   19                        71  34
# ...
#              WASHER, NYLON, 9MM•••••••••••• 137 13 WINDSCREEN ••••••••••••••••••• 137 4
#              WASHER, OIL BOLT•••••••••••••• 93 25 WINKER ASSY., L. FR. ••••••••• 126 4
#                                    104  22 WINKER ASSY., L. RR. ••••••••• 126 7
#              WASHER, PLAIN, 4MM•••••••••••• 112 23 WINKER ASSY., R. FR. ••••••••• 126 1
#                                    128  22 WINKER ASSY., R. RR. ••••••••• 126 6
#              WASHER, PLAIN, 4X8•••••••••••• 95 15 WIRE, HELMET SETTING ••••••••• 146 2
#              WASHER, PLAIN, 5MM•••••••••••• 88 8 WRENCH, BOX •••••••••••••••••• 146 8
#                                    112  24 WRENCH, EYE, 22MM •••••••••••• 146 15
#                                    140  19 WRENCH, EYE, 27MM •••••••••••• 146 16
#              WASHER, PLAIN, 6MM•••••••••••• 128 23 WRENCH, HEX., 5MM •••••••••••• 146 9
#              WASHER, PLAIN, 8MM•••••••••••• 112 25
#                                    113  13
#                                    120  20
#                                    128  23
#                                    134  31
#                                    138   8
#              WASHER, RR. SWINGARM•••••••••• 108 21
#              WASHER, RUBBER•••••••••••••••• 99 8
#              WASHER, SCREEN SETTING•••••••• 137 5
#              WASHER, SEALING, 10.2MM••••••• 71 25
#                                     86   1
#              WASHER, SEALING, 6MM•••••••••• 57 8
#                                     58   8
#                                     59  22
#                                     85   1
#                                     86   1
#              WASHER, SEALING, 6.5MM•••••••• 67 8
#                                     71  27
#                                     85   1
#                                     86   1
#              WASHER, SEALING, 8MM•••••••••• 71 24
#                                     86   1
#              WASHER, SPECIAL, 26X42X2•••••• 77 15
#              WASHER, SPECIAL, 8MM•••••••••• 100 20
#              WASHER, SPLINE, 25MM•••••••••• 76 27
#              WASHER, SPLINE, 25X31X1.5••••• 75 23
#              WASHER, SPLINE, 28MM•••••••••• 76 29
#                                     78  18
#       5      WASHER, SPLINE, 28X34X1.5••••• 76 24
#                                     78  15
#              WASHER, SPLINE, 30X36X1.5••••• 77 13
#              WASHER, SPLINE, 40MM•••••••••• 77 16
#              WASHER, SPRING, 22MM•••••••••• 61 18
#              WASHER, SWINGARM SIDE••••••••• 61 13
#           162
#                                                     2022.08.01 E
#
#
#
#
#
#
#
#
#
#        1      FOREWORD      INDEX
#
#
#
#
#
#
#        2         ENGINE   GROUP
#
#
#
#
#
#
#
#        3          FRAME   GROUP
#
#
#
#
#
#
#
#        4   PART  NUMBER     INDEX
#
#
#
#
#
#
#        5      PART  NAME    INDEX
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                      Published by Honda Motor Co., Ltd.
#             E 2022.08                                                                             Printed in Japan

# %%
import re
import pdfplumber

def extract_section_with_layout(pdf_path: str, section_code: str, section_title: str):
    """
    Finds a specified section, locates 'Reqd. QTY', extracts in layout mode,
    then parses each part and variant into [REF_NO, PART_NO, DESCRIPTION, CATALOGUE_CODE].
    """
    code = section_code.upper()
    title = section_title.upper()

    next_sec_re     = re.compile(r'^[A-Z]+-\d+', re.IGNORECASE)
    table_header_re = re.compile(r'\bReqd\.?\s*QTY\b', re.IGNORECASE)
    part_no_re      = re.compile(r'\b[0-9]{5,}(?:-[A-Z0-9-]+)+\b')

    # Phase 1: locate page range
    start_page = header_hit = None
    end_page = None
    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages):
            for ln in (page.extract_text() or "").splitlines():
                u = ln.strip().upper()
                if start_page is None:
                    if (("FRAMEGROUP" in u and u.startswith(code) and title in u)
                        or (u.startswith(code) and title in u)):
                        start_page = i
                        break
                elif not header_hit:
                    if table_header_re.search(u):
                        header_hit = True
                else:
                    if next_sec_re.match(u) and not u.startswith(code):
                        end_page = i
                        break
            if end_page is not None:
                break
        if start_page is None or not header_hit:
            raise ValueError(f"Section '{section_code} {section_title}' not found or missing table header.")
        if end_page is None:
            end_page = len(pdf.pages)

        # Phase 2: collect layout-preserved lines
        collected = []
        in_table = False
        for pi in range(start_page, end_page):
            layout = pdf.pages[pi].extract_text(layout=True) or ""
            for ln in layout.splitlines():
                u = ln.strip().upper()
                if not in_table:
                    if table_header_re.search(u):
                        in_table = True
                    continue
                if next_sec_re.match(u) and not u.startswith(code):
                    break
                collected.append(ln)

    # Phase 3: group into per-part buffers
    records = []
    last_ref = ""
    for ln in collected:
        m_pno = part_no_re.search(ln)
        if m_pno:
            m_ref = re.match(r'^\s*(?:\((\d+)\)|(\d+))\s+', ln)
            if m_ref:
                last_ref = m_ref.group(1) or m_ref.group(2)
            ref = last_ref
            pno = m_pno.group(0)
            buf = [ln[m_pno.end():].strip()]
            records.append({"ref": ref, "part_no": pno, "buf": buf})
        else:
            if not records:
                continue
            txt = ln.strip()
            if re.fullmatch(r'\d+', txt) or re.fullmatch(r'\d{4}\.\d{2}\.\d{2}', txt):
                continue
            records[-1]["buf"].append(txt)

    # Phase 4: parse each buffer
    out = []
    for rec in records:
        raw = " ".join(rec["buf"])
        raw = raw.replace('∙','').replace('•','').replace('\uf020','')
        raw = re.sub(r'\s+', ' ', raw).strip()

        # split on the first run of dashes
        idx = raw.find("--------")
        desc_part = raw[:idx].strip() if idx != -1 else raw
        cat_part  = raw[idx+8:].strip() if idx != -1 else ""

        # clean description
        desc_part = re.sub(r'\.{2,}\s+\d.*$', '', desc_part).strip()
        desc_part = re.sub(r'\s+GK[A-Za-z0-9]+\s*$', '', desc_part)
        desc_part = re.sub(r'\s+(?:-+|\d+)+\s*$', '', desc_part)
        desc = re.sub(r'\s+\d+\s+\d{4}\.\d{2}\.\d{2}.*$', "", desc_part).strip()
        desc = re.sub(r'(?:\s+(?:\(\d+\)|-+|\d+))+$', "", desc).strip()
        desc = re.sub(r'\.{2,}$', "", desc).strip()
        desc = "" if not re.search(r'[A-Za-z]', desc) else desc

        # extract catalogue codes
        if cat_part.upper().startswith("GK") and len(cat_part) > 8:
            # drop the first 8 chars of GK-prefix, then take up to the first space
            cat_clean = cat_part[8:].split()[0]
        else:
            m_codes   = re.match(r'[-\s]*([0-9A-Z,\s]+)', cat_part)
            raw_codes = m_codes.group(1) if m_codes else ""
            # drop spaces
            cat_clean = raw_codes.replace(" ", "")
            # insert comma between letter and digit runs, e.g. "TH3U" → "TH,3U"
            cat_clean = re.sub(r'([A-Z])(?=\d)', r'\1,', cat_clean)
            # insert comma before any two-letter code glued at the end or before another code
            cat_clean = re.sub(
                r'(?<=[0-9A-Z]{2})(?=[A-Z]{2}(?:,|$))',
                ',',
                cat_clean
            )

        # drop any trailing 4-digit year if present
        cat_clean = re.sub(r'\d{4}$', '', cat_clean)

        tokens = [t for t in cat_clean.split(',') if t]
        seen = set()
        final_codes = [c for c in tokens if c not in seen and not seen.add(c)]
        cat = ",".join(final_codes)

        # suffix-splitting logic unchanged
        m3 = re.match(r'^(.+?)([A-Z]{3,})$', rec["part_no"])
        if m3:
            core, suf = m3.group(1), m3.group(2)
            pno = core + suf[:2]
            desc = f"{suf[2:]} {desc}".strip()
        else:
            pno = rec["part_no"]

        out.append([rec["ref"], pno, desc, cat])

    return out

if __name__ == "__main__":
    pdf_file = "NC750XAP_13MKWM02_PC_2022_2023.pdf"
    for row in extract_section_with_layout(pdf_file, "F-19-40", "REAR WHEEL"):
        print(row)
# Out:
# ['1', '06410-MGS-D30', 'DAMPER SET, WHEEL', '']
# ['2', '41201-MGS-D30', 'SPROCKET, FINAL DRIVEN(43T)', '']
# ['2', '41201-MKW-D10', 'SPROCKET, FINAL DRIVEN(41T)', '']
# ['3', '42301-MGS-D31', 'AXLE, RR. WHEEL', '']
# ['4', '42311-MGS-D10', 'COLLAR, L. RR. WHEEL SIDE', '']
# ['5', '42312-MGS-D10', 'COLLAR, RR. BRAKE SIDE', '']
# ['6', '42515-MGS-D80', 'RING, RR. PULSER', '']
# ['7', '42615-MGS-D30', 'FLANGE SUB ASSY., RR. DRIVEN', '']
# ['8', '42620-MGS-D10', 'COLLAR, RR. AXLE DISTANCE', '']
# ['9', '42625-MGS-D30', 'COLLAR B, RR. WHEEL DISTANCE', '']
# ['10', '42650-MKA-D81ZB', 'WHEEL SUB ASSY., RR. *TYPE1*', '']
# ['11', '42704-MER-D00', 'WEIGHT, BALANCE(10G) N N N N N N', '']
# ['11', '42705-MER-D00', 'WEIGHT, BALANCE(20G) N N N N N N', '']
# ['11', '42706-MER-D00', 'WEIGHT, BALANCE(30G) N N N N N N', '']
# ['12', '42711-MJL-D34', 'TIRE, RR.(DUNLOP) (160/60ZR17 M/C 69W)', '']
# ['12', '42711-MKW-D01', 'TIRE, RR.(METZELER) (160/60ZR17 M/C 69W)', '']
# ['13', '42755-MKA-D81', 'VALVE ASSY., CLAMP IN', '']
# ['14', '42758-MKA-D81', 'O-RING', '']
# ['15', '43251-MGS-D31', 'DISK, RR. BRAKE(SUNSTAR)', '']
# ['16', '90102-MAS-000', 'BOLT, STUD, 12X25', '']
# ['17', '90105-MBB-000', 'BOLT, BRAKE DISK, 8X24', '']
# ['18', '90302-MKT-D01', 'NUT U, FLANGE, 12MM', '']
# ['19', '90306-MCS-G01', 'NUT, U, 18MM', '']
# ['20', '90401-MAS-000', 'WASHER, 20X31.5X2', '']
# ['21', '90559-MKW-D00', 'WASHER, RR. SWINGARM', '']
# ['22', '91051-MGS-D31', 'BEARING, ANGULAR BALL, 22X50X15', '']
# ['23', '91053-MGS-D31', 'BEARING, RADIAL BALL, 6204UU', '']
# ['24', '91251-MGS-D31', 'DUST SEAL, 30X50X7', '']
# ['25', '91253-MAE-003', 'DUST SEAL, 30X47X7.5', '']
# ['26', '91351-MGS-D30', 'O-RING, 55X2', '']

# %%
import re
import pdfplumber

def extract_section_with_layout(pdf_path: str, section_code: str, section_title: str):
    """
    Finds a specified section, locates 'Reqd. QTY', extracts in layout mode,
    then parses each part and variant into [REF_NO, PART_NO, DESCRIPTION, CATALOGUE_CODE].
    """
    code = section_code.upper()
    title = section_title.upper()

    next_sec_re     = re.compile(r'^[A-Z]+-\d+', re.IGNORECASE)
    table_header_re = re.compile(r'\bReqd\.?\s*QTY\b', re.IGNORECASE)
    part_no_re      = re.compile(r'\b[0-9]{5,}(?:-[A-Z0-9-]+)+\b')

    # Phase 1: locate page range
    start_page = header_hit = None
    end_page = None
    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages):
            for ln in (page.extract_text() or "").splitlines():
                u = ln.strip().upper()
                if start_page is None:
                    if (("FRAMEGROUP" in u and u.startswith(code) and title in u)
                        or (u.startswith(code) and title in u)):
                        start_page = i
                        break
                elif not header_hit:
                    if table_header_re.search(u):
                        header_hit = True
                else:
                    if next_sec_re.match(u) and not u.startswith(code):
                        end_page = i
                        break
            if end_page is not None:
                break
        if start_page is None or not header_hit:
            raise ValueError(f"Section '{section_code} {section_title}' not found or missing table header.")
        if end_page is None:
            end_page = len(pdf.pages)

        # Phase 2: collect layout-preserved lines
        collected = []
        in_table = False
        for pi in range(start_page, end_page):
            layout = pdf.pages[pi].extract_text(layout=True) or ""
            for ln in layout.splitlines():
                u = ln.strip().upper()
                if not in_table:
                    if table_header_re.search(u):
                        in_table = True
                    continue
                if next_sec_re.match(u) and not u.startswith(code):
                    break
                collected.append(ln)

    # Phase 3: group into per-part buffers
    records = []
    last_ref = ""
    for ln in collected:
        m_pno = part_no_re.search(ln)
        if m_pno:
            m_ref = re.match(r'^\s*(?:\((\d+)\)|(\d+))\s+', ln)
            if m_ref:
                last_ref = m_ref.group(1) or m_ref.group(2)
            ref = last_ref
            pno = m_pno.group(0)
            buf = [ln[m_pno.end():].strip()]
            records.append({"ref": ref, "part_no": pno, "buf": buf})
        else:
            if not records:
                continue
            txt = ln.strip()
            if re.fullmatch(r'\d+', txt) or re.fullmatch(r'\d{4}\.\d{2}\.\d{2}', txt):
                continue
            records[-1]["buf"].append(txt)

    # Phase 4: parse each buffer
    out = []
    for rec in records:
        raw = " ".join(rec["buf"])
        raw = raw.replace('∙','').replace('•','').replace('\uf020','')
        raw = re.sub(r'\s+', ' ', raw).strip()

        # split on the first run of dashes
        idx = raw.find("--------")
        desc_part = raw[:idx].strip() if idx != -1 else raw
        cat_part  = raw[idx+8:].strip() if idx != -1 else ""

        # clean description
        desc_part = re.sub(r'\.{2,}\s+\d.*$', '', desc_part).strip()
        desc_part = re.sub(r'\s+GK[A-Za-z0-9]+\s*$', '', desc_part)
        desc_part = re.sub(r'\s+(?:-+|\d+)+\s*$', '', desc_part)
        desc = re.sub(r'\s+\d+\s+\d{4}\.\d{2}\.\d{2}.*$', "", desc_part).strip()
        desc = re.sub(r'(?:\s+(?:\(\d+\)|-+|\d+))+$', "", desc).strip()
        desc = re.sub(r'\.{2,}$', "", desc).strip()
        # — NEW: drop trailing single-letter columns like " N N N"
        desc = re.sub(r'(?:\s+[A-Z])+$', '', desc).strip()
        desc = "" if not re.search(r'[A-Za-z]', desc) else desc

        # extract catalogue codes
        if cat_part.upper().startswith("GK") and len(cat_part) > 8:
            cat_clean = cat_part[8:].split()[0]
        else:
            m_codes   = re.match(r'[-\s]*([0-9A-Z,\s]+)', cat_part)
            raw_codes = m_codes.group(1) if m_codes else ""
            cat_clean = raw_codes.replace(" ", "")
            cat_clean = re.sub(r'([A-Z])(?=\d)', r'\1,', cat_clean)
            cat_clean = re.sub(
                r'(?<=[0-9A-Z]{2})(?=[A-Z]{2}(?:,|$))',
                ',',
                cat_clean
            )

        # drop any trailing 4-digit year if present
        cat_clean = re.sub(r'\d{4}$', '', cat_clean)

        tokens = [t for t in cat_clean.split(',') if t]
        seen = set()
        final_codes = [c for c in tokens if c not in seen and not seen.add(c)]
        cat = ",".join(final_codes)

        # suffix-splitting logic unchanged
        m3 = re.match(r'^(.+?)([A-Z]{3,})$', rec["part_no"])
        if m3:
            core, suf = m3.group(1), m3.group(2)
            pno = core + suf[:2]
            desc = f"{suf[2:]} {desc}".strip()
        else:
            pno = rec["part_no"]

        out.append([rec["ref"], pno, desc, cat])

    return out

if __name__ == "__main__":
    pdf_file = "CRF1000 A_PC_13MJPG02_(G.H).pdf"
    for row in extract_section_with_layout(pdf_file, "F-40-2", "MARK/EMBLEM(CRF COLOR)"):
        print(row)
# Out:
# ['1', '86101-MJP-G50ZA', 'MARK , HONDA(65MM) *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U']
# ['2', '86102-MJP-G50ZA', 'MARK , HONDA(55MM) *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['3', '86171-MJP-F50ZA', 'STRIPE A, R. FUEL TANK *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['4', '86172-MJP-F50ZA', 'STRIPE A, L. FUEL TANK *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['5', '86173-MJP-F50ZA', 'STRIPE B, R. FUEL TANK *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['6', '86174-MJP-F50ZA', 'STRIPE B, L. FUEL TANK *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['7', '86211-MJP-G50', 'BADGE, R. PRODUCT', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['8', '86212-MJP-G50', 'BADGE, L. PRODUCT', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['9', '86611-MJP-F50ZA', 'STRIPE , R. FR. FENDER *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['10', '86612-MJP-F50ZA', 'STRIPE , L. FR. FENDER *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['11', '86641-MJP-F50ZA', 'STRIPE A, R. MIDDLE COWL *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['12', '86642-MJP-F50ZA', 'STRIPE A, L. MIDDLE COWL *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['13', '86643-MJP-F50ZA', 'STRIPE B, R. MIDDLE COWL *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['14', '86644-MJP-F50ZA', 'STRIPE B, L. MIDDLE COWL *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['15', '86831-MJP-G50ZA', 'MARK , R. SIDE COVER *TYPE3*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['16', '86832-MJP-G50ZA', 'MARK , L. SIDE COVER *TYPE3*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['06000', '11385-MJF-A00', '151 3 13445-MJP-G50 167 15 14932-MBB-000 148 14 16450-MJP-G51 177 10 17500-MJP-KE0ZA', '']
# ['152', '13446-MJP-G50', '167 16 14933-MBB-000 148 14 16451-MJP-G51 177 11 17503-MBT-D50', '']
# ['152', '06111-MJP-A60', '179 1 11394-MJP-G51 151 4 13447-MJP-G50 167 17 14934-MBB-000 148 14 16472-KPC-D50 177 12 17515-KFB-840', '']
# ['152', '06112-MJP-A60', '180 1 152 9 13481-MJP-G50 167 18 14935-MBB-000 148 14 16610-HL4-003', '']
# ['152', '06112-MJP-A80', '180 1 180 1 14936-MBB-000 148 14 16620-HL4-003 177 14 17515-MEG-300', '']
# ['152', '06406-MJP-G50', '232 1 11395-MJP-G51 162 2 14000 14937-MBB-000 148 14 16630-MFJ-D00 177 15 17526-MJP-G51', '']
# ['152', '06410-MBB-000', '212 1 180 1 14938-MBB-000 148 14 16700-MJP-G51 214 2 17528-MAT-D70', '']
# ['152', '06420-MJP-G50', '212 2 11397-MJP-G81 176 1 14110-MJP-G50 147 3 14939-MBB-000 148 14 16711-MGS-D31 214 3 17541-MJP-G50', '']
# ['152', '06421-MJP-G50', '212 3 180 1 14311-MJP-G50 150 1 14940-MBB-000 148 14 16712-MGS-D31', '']
# ['152', '06422-MJP-G50', '212 4 11398-MJP-G81 154 8 14321-MJP-G50 150 2 14941-MBB-000 148 14 16730-MGS-D31 214 5 17574-MGS-D30', '']
# ['152', '06435-MEJ-016', '209 1 180 1 14401-MJP-G51 150 3 14942-MBB-000 148 14 16958-GJ6-000 214 6 17590-MJP-G50', '']
# ['152', '06435-MEJ-026', '209 1 11520-MJP-G50 164 6 14410-HL4-000 147 4 14943-MBB-000 148 14 223 1 17611-KE8-000', '']
# ['152', '06436-MCT-016', '210 1 11520-MJP-G80 176 2 14420-HL4-000 147 5 14944-MBB-000 149 14 17611-MJP-G50', '']
# ['152', '06440-MJP-G50', '204 1 11530-MJP-G80 176 3 14451-HL4-000 147 6 14945-MBB-000 149 14 17000 17613-KFB-010', '']
# ['152', '06451-443-405', '209 2 14510-MJP-G50 150 4 14946-MBB-000 149 14 17620-MJE-D01', '']
# ['152', '06451-MCZ-006', '202 1 12000 14520-MJP-G51 150 5 14947-MBB-000 149 14 17201-MG9-000 178 16 17621-MGP-D61', '']
# ['152', '06452-MCZ-006', '202 2 14523-HL4-003 150 6 14948-MBB-000 149 14 17210-MJP-G50 220 1 17724-MJP-G50', '']
# ['152', '06455-MJP-G51', '202 3 12010-MJP-G50 145 1 179 1 14949-MBB-000 149 14 17215-MJP-G50 220 2 17910-MJP-G51', '']
# ['152', '06455-MJP-G52', '202 3 12204-HL4-305 145 2 14524-MBB-000 150 7 14950-MBB-000 149 14 17218-MJP-G50', '']
# ['152', '12205-HL4-305', '145 3 14611-MJP-G50 150 8 14951-MBB-000 149 14 17225-MAH-610 247 1 17920-MJP-G51', '']
# ['11000', '12208-413-003', '147 2 14612-MJP-G50 150 9 17226-MJP-G50', '']
# ['11000', '12208-MEG-003', '147 1 14711-HL4-000 147 7 15000 17227-MJP-G50 220 4 17925-MJP-G50', '']
# ['11000', '11000-MJP-DA0', '164 1 12229-HL4-000 144 1 14721-MJP-G50 147 8 17229-MJP-G50', '']
# ['11000', '11000-MJP-DB0', '164 1 179 1 14731-MGE-010 147 9 15010-MCE-H51 162 3 17234-MJP-G50', '']
# ['11000', '11000-MJP-G51', '164 1 12251-MJP-G51 145 4 14751-MJP-G50 147 10 15100-MJP-G50 162 4 17239-MJP-G50', '']
# ['11000', '11000-MJP-G81', '164 1 179 1 14771-HL4-000 147 11 15100-MJP-G51 162 4 17244-MJP-G50', '']
# ['11000', '11000-MJP-H60', '164 1 12300-MJP-G50 144 2 14775-MJP-G50 147 12 15100-MJP-G81 162 5 17245-107-010 247 2 18150-MJP-G50', '']
# ['11000', '11000-MJP-H80', '164 1 12341-MAT-750 144 3 14781-HA0-770 147 13 15104-MGS-D20 152 10 17245-MJP-G50 220 9 18180-MJP-G50', '']
# ['11000', '11104-MJP-G50', '164 2 12391-HL4-000 144 4 14901-MBB-000 147 14 162 6 17250-MJP-G50 220 10 18185-MJP-G50', '']
# ['11000', '11140-MJP-G50', '164 3 179 1 14902-MBB-000 147 14 15130-MJP-G50 162 7 17252-MJP-G50 220 11 18190-MJP-G50', '']
# ['11000', '11206-MJP-G50', '164 4 14903-MBB-000 147 14 15136-MJP-G50 162 8 17256-MJP-G50 220 12 18240-MJP-G50', '']
# ['11000', '11207-MJP-G50', '164 5 13000 14904-MBB-000 147 14 15150-MJP-G50 162 9 17257-MJP-G50 220 13 18291-MM8-880', '']
# ['11000', '11210-MJP-G50', '162 1 14905-MBB-000 147 14 15154-MAT-000 162 10 17265-MJP-G50', '']
# ['11000', '11210-MJP-G51', '162 1 13011-MJP-305 166 2 14906-MBB-000 147 14 180 1 17368-KV7-671 209 3 18293-MJP-G50', '']
# ['11000', '11210-MJP-G80', '162 1 13021-MJP-305 166 2 14907-MBB-000 147 14 15410-MFJ-D01 162 11 17369-KB4-670 220 15 18293-MN0-000', '']
# ['11000', '11210-MJP-G81', '162 1 13101-MJP-G50 166 3 14908-MBB-000 147 14 15412-MGS-D21 152 11 222 2 18309-MJP-G50', '']
# ['11000', '11230-MJP-G50', '166 1 13102-MJP-305 166 3 14909-MBB-000 147 14 15414-MEB-670 152 12 17370-419-700 220 16 18310-MJP-G50', '']
# ['11000', '11320-MJP-G50', '158 1 13111-MJP-G50 166 4 14910-MBB-000 147 14 15421-MJP-G50 162 12 17411-MGZ-A00 223 2 18310-MJP-H60', '']
# ['11000', '11330-MJP-G50', '151 1 13112-MC7-000 166 5 14911-MBB-000 147 14 15516-MGS-D30 164 7 17414-MJP-A60 223 3 18310-MJP-J20', '']
# ['11000', '11330-MJP-G80', '152 1 13210-MJP-G50 166 6 14912-MBB-000 147 14 15611-KA4-710 158 3 17415-KZZ-900 223 4 18316-KFT-620', '']
# ['11000', '11335-MJP-G80', '152 2 13213-MJP-G51 166 7 14913-MBB-000 147 14 15650-MJP-G81 158 4 17415-MJP-A60 223 5 18329-MEN-A30', '']
# ['11000', '11337-MJP-G80', '152 3 13214-MJP-G51 166 8 14914-MBB-000 147 14 15772-551-000 222 1 17416-MJP-G50 214 7 18340-MJP-G50', '']
# ['11000', '11338-MJP-G80', '154 1 13215-MJP-G51 166 8 14915-MBB-000 148 14 17417-MJP-G50 214 8 18345-KTK-000', '']
# ['11000', '11350-MJP-G50', '158 2 13216-MJP-G51 166 8 14916-MBB-000 148 14 16000 17418-MJP-A60 223 6 18345-MBT-610', '']
# ['11000', '11350-MJP-KC0', '159 21 13217-MJP-G51 166 8 14917-MBB-000 148 14 17418-MJP-DA0 223 6 18345-MFJ-D00', '']
# ['11000', '11351-MJP-KC0', '159 22 13218-MJP-G51 166 8 14918-MBB-000 148 14 16075-MEW-921 177 1 17418-MJP-G50 214 9 18365-MEE-D00', '']
# ['11000', '11361-MJP-G80', '152 4 13300-MJP-G50 166 9 14919-MBB-000 148 14 16180-ML6-671 214 1 17419-MJP-A60 223 7 18371-MJP-G50', '']
# ['11000', '11362-MJP-G80', '154 2 13300-MJP-G80 166 9 14920-MBB-000 148 14 16211-MJP-G50 145 5 17419-MJP-DA0 223 7 18380-MJP-G50', '']
# ['11000', '11364-MJP-G80', '154 3 13312-MJP-G51 166 10 14921-MBB-000 148 14 16218-MCA-000 145 6 17419-MJP-G50 214 10 18391-ML0-003', '']
# ['180', '13313-MJP-G51', '166 10 14922-MBB-000 148 14 16218-MJP-G50 145 7 17421-MJP-A60 223 8 18421-MJP-G50', '']
# ['180', '11365-MJP-G80', '154 4 13314-MJP-G51 166 10 14923-MBB-000 148 14 16400-MJP-A61 177 2 17422-MJP-A60 223 9 18422-KR3-870', '']
# ['180', '11366-MJP-G80', '154 5 13315-MJP-G51 166 10 14924-MBB-000 148 14 16400-MJP-G51 177 3 17423-MJP-A60 224 10 18422-MBG-610', '']
# ['180', '11371-MGS-D20', '154 6 13316-MJP-G51 166 10 14925-MBB-000 148 14 16410-MJP-A61 177 4 17500-MJP-DA0ZA 215 11 18422-MJP-G50', '']
# ['180', '13400-MJP-G50', '167 11 14926-MBB-000 148 14 16410-MJP-G51 177 4 17500-MJP-E50ZA 215 11 18423-MGC-N20', '']
# ['180', '11372-MGS-D20', '154 7 13420-MJP-DA0 167 12 14927-MBB-000 148 14 16430-MJP-G51 177 5 17500-MJP-F50ZA 215 11 18423-MJP-G50', '']
# ['180', '11375-MJP-G80', '152 5 13420-MJP-G51 167 12 14928-MBB-000 148 14 16431-MJP-G51 177 6 17500-MJP-G50ZA 215 11 18443-MCW-D60', '']
# ['180', '11376-MJP-G50', '151 2 13430-MJP-G50 167 13 14929-MBB-000 148 14 16432-MJP-G51 177 7 17500-MJP-G50ZB 215 11 18601-KEA-741', '']
# ['180', '11377-MJP-G80', '152 6 13433-MJP-DA0 167 14 14930-MBB-000 148 14 16433-MEW-921 177 8 17500-MJP-KA0ZA 215 11 18612-MJP-G50', '']
# ['180', '11381-MJP-G80', '152 7 13433-MJP-G50 167 14 14931-MBB-000 148 14 16435-MFJ-D01 177 9 17500-MJP-KC0ZB 215 11 18613-MJP-G50', '']
# ['180', '18653-MJP-G50', '222 4 22000 23491-MJP-G50 169 14 174 22 32000 33720-MFA-D01', '']
# ['180', '23491-MJP-G80', '171 7 24705-MJP-G50 228 1 33721-GET-671', '']
# ['19000', '22100-HL4-003', '156 1 23492-HL4-000 171 8 24710-MJP-G50 228 2 32100-MJP-G50 243 3 33728-KPP-T00', '']
# ['19000', '22100-MJP-G50', '155 1 23495-KY1-000 169 15 24724-MBW-D21 228 3 32100-MJP-G60 243 3 33728-MJM-R10', '']
# ['19000', '19010-MJP-A61', '250 1 22116-MJP-G50 155 2 172 8 24781-KE1-000 228 4 32100-MJP-G80 243 3 33729-MCZ-003', '']
# ['19000', '19010-MJP-G51', '250 1 22121-MJP-G51 155 3 23495-MM5-000 169 16 32100-MJP-H60 243 3 33731-MJ0-940', '']
# ['19000', '19010-MJP-T61', '250 1 22125-HP6-A00 155 4 23501-MJP-G50 169 17 28000 32100-MJP-H80 243 3 33731-MJM-R10', '']
# ['19000', '19010-MJP-V11', '250 1 22210-MJP-305 155 5 23501-MJP-G80 172 9 32100-MJP-NC0 243 3 33741-MCW-D00', '']
# ['19000', '19014-KEA-003', '250 2 22325-MJP-G51 155 6 23511-MJP-G50 169 18 28102-ME9-000 157 1 32100-MJP-ND0 243 3 33741-MCW-D01', '']
# ['19000', '19015-MJP-G51', '250 3 22350-MJP-G51 155 7 23511-MJP-G80 171 9 28110-MJP-G50 157 2 32100-MJP-T60 243 3 33741-MS6-921', '']
# ['19000', '19016-KEA-003', '250 4 22361-MJP-G51 155 8 23512-MGE-D00 171 10 28121-MAH-000 157 3 32100-MJP-T80', '']
# ['19000', '19020-MGS-D31', '250 5 22401-MJP-G51 155 9 23521-MJP-G50 169 19 28126-MBB-003 157 4 32102-MJP-G50', '']
# ['19000', '19020-MJP-G51', '250 6 22425-MJP-G51 155 10 23521-MJP-G80 172 10 28131-HL4-000 157 5 32103-MJP-G50', '']
# ['19000', '19025-MJP-G51', '250 7 22500-MJP-G81 156 2 23801-MEE-D00 169 20 28160-MJP-G50 157 6 32103-MJP-G60 245 9 34905-MAS-601', '']
# ['19000', '19035-MJP-G50', '250 8 22711-MJP-G80 156 3 172 11 28333-300-000 229 1 32103-MJP-G80 245 9 34906-447-711', '']
# ['19000', '19036-MJP-G50', '250 9 22712-MJP-G80 156 4 23801-MJP-H60 169 20 28660-RFH-013 154 9 32121-MJP-G50', '']
# ['19000', '19037-GEE-710', '250 10 22720-MJP-G80', '']
# ['19000', '19037-KVB-902', '250 10 22810-MJP-G50 151 7 23812-MJP-G50 158 5 30000 32151-MJP-G50', '']
# ['19000', '19037-MCA-G61', '250 10 22815-413-000 151 8 23812-MJP-H60 158 5 187 5 35010-MJP-G50', '']
# ['19000', '19037-MCJ-K00', '250 10 22815-MGE-D01 171 1 30430-MJP-306 194 1 32155-MJP-G50 243 4 35100-MJP-G51', '']
# ['19000', '19040-MJP-G50', '250 11 22821-MJP-G50 151 9 24000 30430-MJP-307 194 1 32156-MJP-G50 158 6 35101-MJP-G51', '']
# ['19000', '19045-MJP-G50', '250 12 22847-MJP-G50 155 11 30430-MJP-DA1 194 1 32157-MJP-G80 152 15 35105-MFJ-D01', '']
# ['19000', '19046-KVB-902', '250 13 22870-MJP-G51 185 4 24211-MJP-G50 173 1 30430-MJP-G51 194 1 32158-MJP-G80 152 16 35113-MJK-N20', '']
# ['19000', '19046-MCA-G61', '250 13 24211-MJP-G80 174 1 30430-MJP-H61 194 1 32159-MJP-G50 243 5 35121-MJP-G51', '']
# ['19000', '19046-PAA-A00', '250 13 23000 24212-MJP-G50 173 2 30432-MBW-E02 194 2 32401-MJP-G50 241 3 35130-MJP-G51', '']
# ['19000', '19051-KA3-830', '250 14 24212-MJP-G80 174 2 30433-MBW-602 194 3 32401-MJP-G60 241 4 35130-MJP-G61', '']
# ['19000', '19052-MB0-000', '220 19 23103-MJP-G50 155 12 24213-HL4-000 174 3 30510-MJP-G51 245 2 32401-MJP-G80 241 4 35130-MJP-G81', '']
# ['19000', '19052-MFF-D00', '250 15 23103-MJP-G80 156 6 24261-283-000 169 21 30514-MZ7-000 241 1 32406-MJP-G51 241 5 35130-MJP-H61', '']
# ['19000', '19055-MBR-870', '250 13 23104-HL4-000 156 7 172 12 30530-MJP-G51 245 3 32410-MJP-G50 241 6 35130-MJP-H81', '']
# ['19000', '19061-MJP-G50', '252 1 23104-MJP-G50 155 13 24310-MJP-G50 173 3 30540-MJP-G51 245 4 32601-MJP-G50 241 7 35139-MJP-G50', '']
# ['19000', '19080-MJP-G51', '250 16 23115-MW4-000 155 14 24310-MJP-G80 174 4 30700-HL4-A01 245 5 32606-GEV-761 243 6 35160-MGS-D31', '']
# ['19000', '19101-MJP-G50', '252 2 156 8 24312-MJP-G80 174 5 30701-MJP-G51 245 6 32606-MEL-D01 243 7 35200-MJP-G51', '']
# ['19000', '19102-MJP-G50', '252 3 23210-MJP-G80 171 2 24315-HL4-000 174 6 32925-958-000 250 17 35200-MJP-G52', '']
# ['19000', '19103-MJP-G50', '252 4 23211-MJP-G50 169 1 24315-MJP-G50 173 4 31000 35200-MJP-G61', '']
# ['19000', '19104-MJP-G50', '252 5 23213-HL4-000 169 2 24321-KT8-030 174 7 33000 35200-MJP-G62', '']
# ['19000', '19106-GET-000', '252 6 171 3 24322-MM4-000 174 8 31110-MJP-G51 160 1 35200-MJP-G81', '']
# ['19000', '19107-GET-000', '252 7 23220-MJP-G50 169 3 24324-KA3-711 174 9 31120-MJP-G51 160 2 33100-MJP-G51 182 1 35200-MJP-G82', '']
# ['19000', '19125-MJP-G50', '245 1 23220-MJP-G80 172 1 24325-HL4-000 173 5 31120-MJP-G81 160 2 33111-MGH-640 182 2 35200-MJP-H61', '']
# ['19000', '19200-MJP-G50', '151 5 23231-MJP-G80 171 4 174 10 31200-MJP-G51 161 1 33115-KVK-900 222 5 35200-MJP-H81', '']
# ['152', '23405-HL4-000', '156 9 24325-KA3-711 174 11 31201-MEW-921 161 2 224 11 35240-MJP-G61', '']
# ['4', '19226-MJP-G50', '151 6 23406-HL4-000 156 10 24326-KBH-901 174 12 31202-MEW-921 161 3 33301-SA0-741 240 1 35240-MJP-G81', '']
# ['152', '23421-MJP-G50', '169 4 24328-MJP-G80 174 13 31203-MEW-921 161 4 33400-MJP-G51 238 1 35330-MK5-003', '']
# ['180', '23421-MJP-G80', '172 2 24329-KA3-740 174 14 31204-MEW-921 161 5 33400-MJP-G61 239 1 35340-MGS-D31', '']
# ['180', '19300-MCJ-003', '145 8 23422-HL4-000 172 3 24329-MGS-D20 174 15 31205-MEW-921 161 6 33402-KWR-003', '']
# ['180', '19305-KV3-010', '145 9 23431-MJP-G50 169 5 24430-HL4-000 174 16 31206-MEW-921 161 7 33402-MJC-D01', '']
# ['180', '19321-MJP-G50', '145 10 23441-MJP-G50 169 6 24430-MJP-G50 173 6 31207-KS5-901 161 8 33450-MJP-G51 238 4 35350-MJP-G51', '']
# ['180', '19501-MJP-G50', '252 8 23441-MJP-G80 172 4 24433-MJP-G80 174 17 31208-MEW-921 161 9 33450-MJP-G61 239 2 35357-HN8-000', '']
# ['180', '19504-KY1-003', '252 9 23442-MS2-610 169 7 24434-MJP-G80 174 18 31209-MEW-921 161 10 33452-KWR-003 238 5 35500-MEH-661', '']
# ['180', '19505-ML3-770', '252 10 23451-MJP-G50 169 8 24435-MJP-G50 173 7 31210-MEW-921 161 11 33452-MJC-D01 238 6 35600-MK4-860', '']
# ['180', '19511-MJP-G50', '252 11 23451-MJP-G80 171 5 24435-MJP-G80 174 19 31300-MJP-G81 176 7 33600-MJP-G51 238 7 35700-MJP-G51', '']
# ['180', '19511-MJP-G80', '252 11 23461-MJP-G50 169 9 24610-MJP-G50 173 8 31500-MBR-871 241 2 33600-MJP-G61 239 3 35759-MJP-G51', '']
# ['180', '19513-MJP-G50', '252 12 23461-MJP-G80 172 5 24610-MJP-G80 174 20 31500-MGE-H51 241 2 33607-MFL-761 238 8 35850-MFT-641', '']
# ['180', '19514-MJP-G50', '252 13 23462-MAT-000 169 10 24613-MJP-G50 173 9 31500-MGE-T21 241 2 33611-MEE-D00 238 9 35856-MJP-G51', '']
# ['180', '19517-ML7-691', '252 14 172 6 24615-MGE-D01 176 4 31500-MJP-NC1', '']
# ['180', '19521-MJP-G50', '252 15 23463-MJP-G50 169 11 24616-MGS-D21 176 5 31500-Z25-C61 241 2 33612-MEE-D00', '']
# ['180', '19521-MJP-G80', '252 16 23471-MJP-G80 171 6 24617-MGE-D01 176 6 31600-MGZ-J01', '']
# ['180', '19530-MJP-G80', '252 17 23481-MJP-G50 169 12 24651-KR3-000 173 10 31700-MM8-610 243 1 33650-MJP-G51 238 11 36162-KZL-931', '']
# ['180', '23481-MJP-G80', '172 7 24651-MGS-D20 174 21 31730-MAS-601 243 2 33650-MJP-G61 239 6 36450-KVK-902', '']
# ['180', '23482-MR7-000', '169 13 24652-HA0-000 173 11 31909-MJP-G51 145 11 33701-MJP-G51 240 2 36531-MJP-G51', '']
# ['37000', '38770-MJP-H81', '245 11 43000 44000 191 11 50707-MJP-G50', '']
# ['37000', '38770-MJP-KC1', '245 11 45518-MM5-006 189 11 50715-MJP-G50ZA', '']
# ['37000', '37100-MJP-B61', '183 1 38770-MJP-KD1 246 11 43107-KT7-761 209 5 44301-MJP-G50 204 3 191 12 50716-MJP-G50', '']
# ['37000', '37100-MJP-G51', '183 1 38770-MJP-NC1 245 11 43108-MBB-006 209 6 44302-MJP-G50 204 4 45520-MG7-006 205 14 50718-KT7-761', '']
# ['37000', '37100-MJP-G61', '183 1 38770-MJP-ND1 246 11 43110-MJP-G51 209 7 44311-MJP-G50 204 5 207 19 50720-KT7-761', '']
# ['37000', '37100-MJP-G81', '183 1 38770-MJP-T61 245 11 43110-MJP-G61 209 7 44515-MJP-G60 204 6 45520-MM5-006 189 12 50725-MJP-G50ZA', '']
# ['37000', '37100-MJP-H61', '183 1 38770-MJP-T81 245 11 43110-MJP-G81 209 8 44620-MJP-G50 204 7 191 13 50730-KT7-761', '']
# ['37000', '37100-MJP-H81', '183 1 38770-MJP-TA1 245 11 43112-MV9-016 209 9 44635-MJP-G50 204 8 45521-HA2-006', '']
# ['37000', '37100-MJP-T61', '183 1 38770-MJP-TB1 246 11 43131-KW3-006 209 10 44650-MJP-E50', '']
# ['37000', '37100-MJP-T81', '183 1 38770-MJP-UC1 245 11 43132-KT7-761 209 11 44650-MJP-G50 204 9 45523-KA3-731', '']
# ['37000', '37100-MJP-U21', '183 1 38770-MJP-UD1 246 11 43150-MJP-G51 209 12 44701-MJP-E51 204 10 191 14 51400-MJP-G51', '']
# ['37000', '37100-MJP-U41', '183 1 38770-MJP-UG1 245 11 43150-MJP-G61 209 12 44701-MJP-G61 204 10 45530-MA4-671 189 14 51400-MJP-G81', '']
# ['37000', '37100-MJP-U51', '183 1 38770-MJP-V11 245 11 43150-MJP-G81 209 12 44711-MJP-G51 204 11 191 15 51401-MJP-G51', '']
# ['37000', '37100-MJP-V11', '183 1 38800-MJP-G81 164 15 43155-MJP-G50 205 1 44712-400-004 204 12 51404-MJP-G51', '']
# ['37000', '37105-MJP-G51', '183 2 38805-MJP-G80 164 16 207 1 44713-KS6-641 204 13 46000 51406-MW4-003', '']
# ['37000', '37110-MJP-B61', '183 3 38810-MJP-G81 152 17 43155-MJP-G80 207 2 51410-MJP-G51', '']
# ['37000', '37110-MJP-G51', '183 3 43156-MJP-G60 207 3 45000 46182-MEL-D21 205 16 51412-KZ3-003', '']
# ['37000', '37110-MJP-G61', '183 3 39000 43156-MJP-G80 207 4 208 21 51414-MFR-671', '']
# ['37000', '37110-MJP-G81', '183 3 43157-MJP-G50 205 2 45103-MR7-006 202 7 46184-611-000 210 11 51415-MFR-671', '']
# ['37000', '37110-MJP-H61', '183 3 39119-MJG-640 254 3 43157-MJP-G80 207 5 45106-MJP-G51 202 8 46401-TM8-A01 220 21 51421-KAE-871', '']
# ['37000', '37110-MJP-H81', '183 3 256 2 43158-MJP-G50 205 3 45107-MJP-G51 202 9 46500-MJP-G50 228 8 51425-MJP-G51', '']
# ['37000', '37110-MJP-T61', '183 3 207 6 45111-MA3-006 209 16 46502-MJP-G50 228 9 51430-MJP-G51', '']
# ['37000', '37110-MJP-T81', '183 3 40000 43208-MCT-006 210 2 45111-MAJ-G41 209 17 46504-MAL-601 205 17 51441-MJP-G51', '']
# ['37000', '37110-MJP-U21', '183 3 43215-KZ4-J41 209 13 45111-MCT-006 210 8 208 22 51447-KZ3-003', '']
# ['37000', '37110-MJP-U41', '183 3 40510-MJP-G50 232 2 43215-MCT-006 210 3 45117-MJP-G51 202 10 46513-MJP-G50 228 10 51451-MAJ-G41', '']
# ['37000', '37110-MJP-U51', '183 3 40535-MJM-D01 232 3 43230-MJP-G80 210 4 45120-MJP-G51 204 14 46525-KK0-003 229 2 51454-MJP-G51', '']
# ['37000', '37110-MJP-V11', '183 3 40540-MJP-G51 232 4 43250-MJP-G81 210 5 45125-MJP-G51 189 2 51490-MJP-G51', '']
# ['37000', '37215-MGC-N40', '183 4 43251-MJP-G51 213 21 45125-MJP-G61 191 2 50000 51497-MEL-000', '']
# ['37000', '37260-MGE-641', '164 11 41000 43290-MJP-G81 210 6 45126-MJP-G51 189 3 51500-MJP-G51', '']
# ['37000', '37610-MJP-G51', '183 5 43310-MJP-G51 205 4 45126-MJP-G61 193 1 50100-MJP-G50ZA 247 4 51500-MJP-G61', '']
# ['37000', '37620-MJP-G51', '184 6 41201-MJP-G51 212 5 43310-MJP-G61 207 7 45127-MJP-G61 193 2 50170-MJP-G50ZA 247 5 51500-MJP-G81', '']
# ['37000', '37700-MJE-D01', '164 12 43311-MJP-G61 207 8 45128-MJP-G61 191 3 50291-MCW-D00 236 2 51525-MJP-G51', '']
# ['37000', '37710-MJP-G81', '164 13 42000 43320-MJP-G60 207 9 45129-MJP-G61 191 4 50318-041-600 236 3 51525-MJP-G61', '']
# ['37000', '37750-KPH-701', '164 14 43352-568-003 202 5 45132-166-016 210 9 50345-MJP-G60', '']
# ['37000', '37800-MJP-G51', '215 24 42301-MJP-G50 212 6 209 14 45133-166-016 210 10 50351-MJP-G50ZA', '']
# ['37000', '37870-MGS-D31', '145 12 42305-MJP-G50 212 7 43353-461-771 202 6 45133-MA3-006 209 18 50352-MJP-G50', '']
# ['37000', '37880-KWW-C01', '220 20 42311-MJP-G50 212 8 209 15 45135-MJP-G60 193 3 50353-MJP-G50 247 8 52101-MJP-G50', '']
# ['37000', '37880-MJP-G51', '182 3 42312-MGS-D30 212 9 43362-MGS-D71 210 7 45136-MJP-G60 193 4 50354-MJP-G50 247 9 52141-MJP-G50', '']
# ['37000', '42515-MJP-G60', '212 10 43450-MJP-G81 211 2 45137-MJP-G60 193 5 50355-MJP-G50 247 10 52142-MJP-G50', '']
# ['38000', '42615-MJP-G51', '212 11 43455-MJP-G80 211 3 45150-MJP-G51 202 11 50356-MJP-G50 247 11 52143-MJP-G50', '']
# ['38000', '42620-MJP-G50', '212 12 43503-MAH-671 205 5 45156-MJP-G50 189 4 50357-MJP-G50 247 12 52156-MJP-G50', '']
# ['38000', '38110-KCR-J01', '243 8 42625-MJP-G50 212 13 207 10 191 5 50358-MJP-G50ZA 247 13 52157-MJP-G50', '']
# ['38000', '38200-MJP-G50', '243 9 42635-MJP-G50 212 14 43504-MB2-006 205 6 45157-MJP-G50 189 5 50359-MJP-G50 247 14 52161-KZZ-900', '']
# ['38000', '38235-S04-003', '258 1 42635-MJP-G60 212 14 207 11 191 6 50361-MJP-G50ZA 247 15 52170-MJP-G50', '']
# ['38000', '38301-MJE-D01', '243 10 42650-MJP-E50 212 15 43510-MJP-G51 205 7 45220-MJP-G51 204 15 50362-MJP-G50 248 16 52171-KR6-000', '']
# ['38000', '38301-MJP-G61', '243 11 42650-MJP-E60 212 15 207 12 45220-MJP-G61 204 15 50530-MJP-G50 231 2 52171-MAN-620', '']
# ['38000', '38306-KK4-000', '243 12 42650-MJP-G50 212 15 43511-KV3-831 205 8 45250-MJP-G51 202 12 50531-GGK-000 231 3 52200-MJP-G50', '']
# ['38000', '38306-MGH-640', '243 13 42650-MJP-G60 212 15 207 13 45423-KA4-700 228 7 50542-KCM-620 231 4 52400-MJP-E51', '']
# ['38000', '38501-KWN-901', '244 14 42701-MJP-E51 212 16 43512-MJP-G51 205 9 45504-410-003 189 6 50601-MJP-G50 231 5 52400-MJP-G51', '']
# ['38000', '38506-KVS-600', '244 15 42701-MJP-G61 212 16 207 14 191 7 50603-033-010 229 3 52400-MJP-H41', '']
# ['38000', '38510-MJP-G61', '209 4 42704-MEG-003 204 2 43514-KS6-701 205 10 45510-MJP-G51 189 7 50603-MFJ-D00 229 4 52400-MJP-H61', '']
# ['38000', '38520-MJP-G61', '202 4 212 17 207 15 191 8 50607-MJP-G50 229 5 52400-MJP-NC1', '']
# ['38000', '38610-MJP-G81', '154 10 42705-MEG-003 204 2 43520-MJ6-315 205 11 45513-KK1-771 205 13 50615-MJP-G50ZA 229 6 52400-MJP-NE1', '']
# ['38000', '38770-MJP-DA1', '245 11 212 17 207 16 207 18 50616-MJP-G50 229 7 52400-MJP-T61', '']
# ['38000', '38770-MJP-DB1', '245 11 42711-MJP-G51 213 18 43530-MJ0-006 205 12 45513-MM5-016 189 8 50617-KFB-840 229 8 52400-MJP-TC1', '']
# ['38000', '38770-MJP-G52', '245 11 42712-MGC-N21 213 19 207 17 191 9 50625-MJP-G50ZA 229 9 52400-MJP-V11', '']
# ['38000', '38770-MJP-G62', '245 11 42713-MGC-N21 213 20 45517-166-006 189 9 50642-MJP-G50 229 10 52400-MJP-V21', '']
# ['38000', '38770-MJP-G82', '245 11 191 10 50661-MJP-G50 229 11 52462-MJP-G50', '']
# ['38000', '38770-MJP-H61', '245 11 45518-MEN-J01 189 10 50662-MJP-G50 229 12 52463-MJP-G50', '']
# ['38000', '52464-MJP-G50', '234 4 57000 64581-MJP-G50 254 15 80122-MJP-G50 241 11 86211-MJP-G50 261 3 87512-MJP-G51', '']
# ['38000', '52465-MJP-G50', '234 5 64582-MJP-G50 254 16 80123-MJP-G50 241 12 264 5 87516-KFK-750', '']
# ['38000', '52472-MJP-G50', '234 6 57110-MJP-G61 193 7 64586-MBW-D20 254 17 80126-MJP-G50 258 3 265 7 87516-KZZ-L40', '']
# ['38000', '52475-MJP-G50', '234 7 64591-MJP-G50 254 18 80127-MJP-G50 246 12 86212-MJP-G50 261 4 87516-MCA-G60', '']
# ['38000', '52491-MCA-000', '248 17 61000 64611-MJP-G50 257 9 80128-MJP-G50 241 13 264 6 87516-MGS-T70', '']
# ['38000', '64711-MJP-G50', '257 10 80129-MJP-G50 241 14 265 8 87516-MJF-H10', '']
# ['53000', '61000-MJP-E50ZA', '198 2 64712-MJP-G50 257 11 86611-MJP-E50ZA 264 7 87520-MGH-K00', '']
# ['53000', '61000-MJP-F50ZA', '198 2 64761-MJP-G50 257 12 81000 86611-MJP-F50ZA 265 9 87541-MFL-750', '']
# ['53000', '53100-MJP-E80', '194 11 61100-MJP-G50 198 3 86612-MJP-E50ZA 264 8 87541-MGE-680', '']
# ['53000', '53100-MJP-G80', '194 11 61101-MJP-G50 198 4 67000 81218-GFM-D30 259 2 86612-MJP-F50ZA 265 10 87541-MGE-T20', '']
# ['53000', '53104-MJP-G50', '194 12 61102-MJP-G50 198 5 81218-KFG-900 260 19 86641-MJP-DA0ZA 261 5 87541-MGH-R00', '']
# ['53000', '53105-MJP-E50', '194 13 61103-MJP-G50 182 4 67311-MJP-G50 255 30 81218-KYZ-T00 259 3 86641-MJP-E50ZA 264 9 87541-MJP-G50', '']
# ['53000', '53105-MJP-G50', '194 13 61104-428-000 193 8 81300-MJP-G50ZA 218 4 86641-MJP-F50ZA 265 11 87560-KVB-900', '']
# ['53000', '53106-MJP-G50', '194 14 222 7 77000 81300-MJP-G50ZB 218 4 86641-MJP-G50ZA 261 5 87560-KVB-930', '']
# ['53000', '53107-MJP-G50', '194 15 224 13 81301-MJP-G50 218 5 86641-MJP-G50ZB 261 5 87560-MBR-871', '']
# ['53000', '53108-MJP-G50', '194 16 61105-MJP-G50 198 6 77100-MJP-F51ZA 216 1 81306-MJP-G50 218 6 86642-MJP-DA0ZA 261 6 87560-MGE-680', '']
# ['53000', '53109-MJP-G50', '194 17 61304-HB3-003 186 20 77100-MJP-G51ZA 216 1 86642-MJP-E50ZA 264 10 87560-MGP-F01', '']
# ['53000', '53111-MJP-G50', '185 10 191 18 77100-MJP-G51ZB 216 1 83000 86642-MJP-F50ZA 265 12 87562-MGE-680', '']
# ['187', '77110-KA3-730', '216 2 86642-MJP-G50ZA 261 6 87586-MGN-D00', '']
# ['187', '53112-MJP-G50', '185 11 61316-KCJ-661 255 32 77156-MJP-G51 216 3 83430-MJP-KC0 215 36 86642-MJP-G50ZB 261 6 87700-KPP-T00ZA', '']
# ['187', '53125-174-670', '236 4 77206-GF0-000 216 4 83505-KGB-610 227 27 86643-MJP-DA0ZA 262 7 87700-KPP-T00ZB', '']
# ['187', '53131-MJP-G80', '194 18 64000 77208-KW7-900 193 9 83545-KCJ-690 220 22 86643-MJP-E50ZA', '']
# ['187', '53132-MJP-G80', '195 19 77212-MFJ-D00 257 13 83551-GE2-000 215 28 86643-MJP-F50ZA', '']
# ['187', '53135-MJP-G50', '195 20 64200-MJP-H60 254 9 77216-KG1-920 218 1 251 20 86643-MJP-G50ZA', '']
# ['187', '53136-MJP-G50', '195 21 64205-166-610 254 4 77220-MJF-A01 216 5 254 19 86643-MJP-G50ZB 261 7 88130-MFG-D00', '']
# ['187', '53140-MGE-000', '185 12 64211-MJP-G50 254 5 77235-MJE-D00 216 6 83605-MY5-G30', '']
# ['187', '64212-MJP-G50', '251 18 77236-KAZ-780 236 5 83610-MJP-DA0ZA 218 7 86644-MJP-DA0ZA 262 8 88210-MGS-D30', '']
# ['187', '53166-MGE-000', '185 13 64220-MJP-G50 254 6 77239-MJM-D61 216 7 83610-MJP-E50ZA 218 7 86644-MJP-E50ZA 264 12 88210-MJP-G80', '']
# ['187', '64221-MJP-G50', '254 7 77251-GR1-000 258 2 83610-MJP-G50ZA 218 7 86644-MJP-F50ZA 265 14 88220-MGS-D30', '']
# ['187', '53170-MEJ-016', '189 15 64230-MJP-G50 254 8 77281-MFL-D20 215 26 83610-MJP-G50ZB 218 7 86644-MJP-G50ZA', '']
# ['191', '64231-MJP-NC0', '255 33 77300-MJP-DA0ZA 216 8 83610-MJP-G50ZC 218 7 86644-MJP-G50ZB', '']
# ['191', '53172-MJP-G50', '185 14 64250-MJP-G50ZA 254 9 77300-MJP-DA0ZB 216 8 83620-MJP-G50 218 8 86831-MJP-DA0ZA', '']
# ['191', '53172-MJP-G80', '211 4 64310-MJP-DA0ZA 256 3 77300-MJP-DA0ZC 216 8 83710-MJP-DA0ZA 219 9 86831-MJP-E50ZA', '']
# ['191', '53174-KA3-730', '185 15 64310-MJP-E50ZA 256 3 77300-MJP-G51ZA 216 8 83710-MJP-E50ZA 218 9 86831-MJP-G50ZA 266 15 89050-MJP-G50', '']
# ['211', '64310-MJP-F50ZA', '256 3 77300-MJP-G51ZB 216 8 83710-MJP-G50ZA 218 9 86831-MJP-G50ZB 262 9 89101-MBW-000', '']
# ['211', '53175-MJP-G80', '211 6 64310-MJP-G50ZA 256 3 77300-MJP-G51ZC 216 8 83710-MJP-G50ZB 219 9 86831-MJP-G50ZC 262 9 89102-538-000', '']
# ['211', '53178-MJP-G50', '185 16 64310-MJP-G50ZB 256 3 77302-124-000 251 19 83710-MJP-G50ZC 218 9 86832-MJP-DA0ZA 263 10 89103-538-000', '']
# ['211', '53178-MJP-G80', '211 7 64312-MJP-G50 254 10 77321-MJP-G50 217 9 219 9 86832-MJP-E50ZA 264 14 89216-HL4-A00', '']
# ['211', '53180-MJP-G60ZA', '196 1 64320-MJP-G51 256 4 77500-MJP-F50ZB 216 1 83720-MJP-G50 219 10 86832-MJP-G50ZA 266 16 89221-MGZ-J00', '']
# ['211', '53180-MJP-G60ZB', '196 1 64360-MJP-DA0ZA 256 5 77500-MJP-G50ZC 216 1 86832-MJP-G50ZB', '']
# ['4', '53185-MJP-G60ZA', '196 2 64360-MJP-E50ZA 256 5 77500-MJP-G50ZD 216 1 84000 86832-MJP-G50ZC', '']
# ['4', '53185-MJP-G60ZB', '196 2 64360-MJP-F50ZA 256 5 77582-MJP-G50', '']
# ['4', '53191-MJP-G60', '191 17 64360-MJP-G50ZA 256 5 84701-MJP-R60 236 9 87000 90001-MGZ-J00', '']
# ['4', '53192-MCJ-000', '185 17 64360-MJP-G50ZB 256 5 80000 90001-MJP-G50', '']
# ['4', '53192-MJP-G80', '211 8 64370-MJP-G51 256 6 86000 87125-MKA-D80', '']
# ['4', '53193-MJP-G80', '211 9 64382-MM5-300 215 25 80101-283-000 248 20 87501-KSV-P00 259 15 90002-MJP-G50', '']
# ['4', '53194-MJP-G80', '211 10 64401-MJP-G50 158 7 80101-310-000 240 11 86101-MJP-G50ZA 261 1 87501-MKA-P00 259 15 90002-MJP-G80', '']
# ['4', '53195-MJP-G80', '211 11 64402-MJP-G50 158 8 80102-MJS-A90 215 27 264 1 87505-MJP-DA0 260 26 90002-PA6-003', '']
# ['4', '53196-MJP-G60', '185 18 64403-MJP-G50 158 9 80102-MJS-J70 224 14 265 1 87505-MJP-G50 259 4 90003-MCS-000', '']
# ['211', '64440-MJP-G60', '248 18 80103-MG2-000 218 2 86102-MJP-G50ZA 261 2 87505-MJP-H60 260 20 90003-MJP-G50', '']
# ['211', '53214-371-010', '197 1 64450-MJP-G50 248 19 80105-MJP-G50 236 6 264 2 87505-MJP-NC0', '']
# ['211', '53214-KZZ-901', '197 2 64501-MJP-G50 254 11 80106-MJP-G50 236 7 265 2 87505-MJP-T60', '']
# ['211', '53219-MJP-G50', '197 3 64521-MJP-G50 257 7 80110-MJP-G50ZA 236 8 86150-KPG-902 195 23 87505-MJP-TA0 260 20 90004-GHB-600', '']
# ['211', '53229-MN1-650', '197 4 64531-MJP-G50 254 12 80110-MJP-H60ZA 236 8 86171-MJP-E50ZA 264 3 87505-MJP-V10 260 16 90004-GHB-630', '']
# ['211', '53300-MJP-G50', '195 22 64531-MJP-G60 254 12 80110-MJP-R60ZA 236 8 86171-MJP-F50ZA 265 3 87507-MFF-A50', '']
# ['211', '53781-SE0-952', '186 19 64531-MJP-G80 254 12 80118-MFJ-D00 198 7 86172-MJP-E50ZA 264 4 87507-MGZ-T10 259 7 90004-GHB-640', '']
# ['187', '64532-MJP-G50', '254 13 217 11 86172-MJP-F50ZA 265 4 87508-MJJ-D31 259 8 90004-MJP-G50', '']
# ['244', '64541-MJP-G50', '254 14 218 3 86173-MJP-F50ZA 265 5 87509-KWW-A40', '']
# ['244', '64571-MJP-G50', '257 8 80121-MJP-G50 241 10 86174-MJP-F50ZA 265 6 87509-MGE-680', '']
# ['244', '90004-MJP-G50', '158 11 90082-HA0-000 150 13 255 23 236 16 90452-MCA-000 171 13 90661-MEW-921', '']
# ['244', '90005-MJP-G50', '154 13 90084-MN8-010 158 13 257 17 17 90452-MR7-000 170 24 90666-SDA-A01', '']
# ['244', '90005-MJP-G80', '165 20 90085-MGC-920 151 11 90117-KPM-000 198 8 241 17 90453-KSR-A00 170 25 90677-KAN-961', '']
# ['244', '90006-GHB-610', '244 17 152 25 255 34 246 14 90455-ML7-000', '']
# ['244', '90006-GHB-630', '252 19 236 10 90117-MFL-D20', '']
# ['244', '90006-GHB-680', '162 13 90087-MJP-G50 158 14 90117-MJP-G50 186 26 90304-GE8-003 195 27 90458-729-920', '']
# ['244', '90006-GHB-710', '145 14 90089-KAS-900 156 11 211 17 90304-MCS-G01 235 14 90459-438-000', '']
# ['244', '90006-MJP-G50', '158 12 90101-K29-900 210 12 90117-MJP-G60 202 15 90304-ME1-670 227 32 172 16 90683-KJ2-003', '']
# ['244', '90007-HL4-003', '145 15 90101-MGS-D70 210 13 209 19 90304-MJ4-670 195 28 90463-HL4-000 171 14 90690-GHB-611', '']
# ['244', '90007-MJP-G50', '164 17 90102-MAS-000 213 22 90118-MJN-A00 230 22 90304-MJP-G50 204 18 90463-MAT-000', '']
# ['244', '90008-MJP-G50', '150 11 90102-MJP-G50 248 21 90118-MJP-G50 255 24 90305-MBZ-C50 232 20 172 17 90690-GHB-671', '']
# ['244', '90010-GHB-670', '150 12 90103-KWT-900 236 11 90118-MR1-000 230 23 90306-KF0-003 213 25 90463-MCJ-000 170 30 90690-GHB-691', '']
# ['244', '90010-MCH-000', '157 7 90103-MEN-710 163 16 90119-SD9-000 165 27 90306-KTZ-D01 235 15 90464-MAT-000 170 31 90690-GHB-711', '']
# ['244', '90010-MJP-G80', '176 9 90103-MY1-000 248 22 90120-KCR-003 251 23 90306-MCS-G01 213 26 172 18 90690-MEF-800', '']
# ['244', '90011-MGE-D00', '152 22 90104-MJP-G51 202 14 90120-MFL-D20 236 15 90309-357-000 232 21 90464-MCJ-000', '']
# ['165', '90105-MBB-000', '213 23 258 9 90310-MGS-D31 186 30 90488-425-000 151 12 90690-MGS-D81', '']
# ['165', '90011-MGP-000', '165 22 90105-MJP-G50 231 6 90122-MJP-G80 211 18 187 17 153 27 90701-KAS-900', '']
# ['165', '90011-MJP-G80', '176 10 90106-MBB-000 204 16 90123-MJP-G50 202 16 90312-GF0-000 246 15 165 31 90701-MV9-670', '']
# ['165', '90012-MGE-000', '149 15 90106-MCF-D00 232 16 90126-MCH-A00 211 19 90313-HE0-006 210 15 180 1 90841-001-000', '']
# ['165', '90013-GHB-600', '189 16 90106-MCW-D00 196 3 90126-MJP-G50 234 9 90315-MFL-003 251 26 90493-MGE-D00 171 15 90899-422-610', '']
# ['191', '90106-MJP-G50', '254 20 90127-KF0-770 186 27 90320-GC3-000 251 24 90501-GN5-830', '']
# ['191', '90013-GHB-610', '205 18 257 15 191 24 90321-MCJ-000 186 31 90501-MJ6-000', '']
# ['208', '90107-KSE-000', '186 25 211 20 211 21 90501-MJP-G50', '']
# ['211', '90321-MJP-G60', '248 26 90501-MJP-R60 236 18 91001-MJP-G51', '']
# ['211', '90013-GHB-620', '189 17 90107-MBG-000 195 25 90127-MJP-G50 234 10 90401-KZ4-890 213 27 90504-964-000 255 26 91002-MCH-003', '']
# ['191', '90107-MJP-G50', '205 20 90128-KL4-000 248 25 90401-MEA-670 155 18 90505-425-000 150 15 91002-MJP-305', '']
# ['205', '90128-MJP-G50', '234 11 90401-MS2-610 155 19 90508-MGE-D00 186 32 91002-MJP-G53', '']
# ['208', '90129-MJP-G50', '234 12 90401-ZVA-000 198 10 187 18 91003-MJP-G81', '']
# ['208', '90013-GHB-660', '186 24 90108-KSV-J00 232 18 90130-MGS-D31 186 28 90401-ZW6-000 198 10 90509-MJP-G50 236 19 91004-MJP-G81', '']
# ['189', '90109-MBT-611', '227 28 187 16 90402-GB0-900 237 25 90510-MJP-G50 219 11 91005-MJP-G51', '']
# ['191', '90109-MR7-000', '195 26 90130-MJP-G50 235 13 90402-MJP-G50 167 21 90512-MJP-G60 248 27 91007-MGS-D31', '']
# ['211', '90131-883-000', '163 17 90403-HL4-000 156 13 90526-GB0-930', '']
# ['211', '90013-GHB-670', '189 19 199 19 90131-KPB-751 204 17 90403-KA3-830 193 13 90543-MV9-670 144 9 91009-GE0-004', '']
# ['191', '90110-MGP-D60', '215 29 213 24 90403-MEW-920 160 5 179 1 91015-KT8-005', '']
# ['191', '90013-MJP-G50', '155 15 90111-162-000 252 20 90132-MFJ-D00 227 31 90403-MK2-300 171 11 90544-KF0-000 145 18 91015-MJP-G51', '']
# ['167', '90111-KW3-003', '255 21 90136-428-870 215 30 90404-HL4-000 156 14 179 1 91016-KT8-005', '']
# ['167', '90015-MJP-G50', '165 23 90111-KZZ-900 193 10 90145-MR8-014 189 21 90404-HW1-670 153 26 90544-KS7-003 199 20 91016-MJP-G51', '']
# ['167', '90016-MJP-G50', '165 24 90111-MGS-D70 255 31 192 25 180 1 90545-300-000 189 23 91017-MJP-G51', '']
# ['167', '90017-MA6-000', '145 16 90111-MR5-000 241 15 90145-MS9-612 189 22 90404-MJP-G50 167 22 192 27 91018-HL4-003', '']
# ['167', '90017-MAL-600', '144 8 90112-KWT-900 229 20 192 26 90405-MFA-D00 167 23 193 14 91023-HL4-003', '']
# ['167', '90019-MB0-000', '162 14 90112-MBB-000 227 29 193 11 90406-MJP-G50 163 18 206 22 91023-MM5-641', '']
# ['167', '90020-MBW-610', '195 24 90113-GFP-B00 227 30 206 21 90414-MGE-D00', '']
# ['167', '90021-MGZ-D02', '178 17 90113-KT0-670 248 23 208 26 90417-360-000 173 14 90545-KF0-000 153 28 91024-HL4-003', '']
# ['167', '90021-MM5-000', '173 12 90114-MA5-671 189 20 90147-MCE-950 231 7 90432-MM8-003 155 21 180 1 91024-MGS-D21', '']
# ['174', '90114-MGE-000', '158 15 90155-MBL-610 230 24 90442-028-000 165 28 90603-MN4-000 170 33 91025-MGS-D21', '']
# ['174', '90022-MJP-G50', '162 15 236 12 90161-MM8-000 255 25 180 1 90604-MCA-780 171 16 91026-MGS-D21', '']
# ['174', '90023-MJP-G50', '160 4 255 22 90180-MGS-D71 210 14 90442-397-000 150 14 90604-MM5-000 170 34 91026-MV9-671', '']
# ['174', '90023-MR5-670', '173 13 257 16 90180-MN8-006 209 20 179 1 172 19 91027-MGS-D21', '']
# ['174', '90031-MJP-G80', '152 23 90114-MGE-D00 229 21 90201-415-000 215 31 90443-MB0-000 165 29 90605-MGE-D00 171 17 91028-MGS-D21', '']
# ['174', '90032-MJP-G50', '145 17 232 19 90201-HL4-000 156 12 180 1 90617-SA0-003 244 18 91051-MAS-003', '']
# ['174', '90037-422-003', '169 22 241 16 90203-MF9-710 231 8 90443-MJ6-000 165 30 90620-SB2-003 244 19 91052-MGS-D31', '']
# ['172', '90206-KM3-000', '149 16 180 1 90650-KV6-003 240 14 91053-MFJ-D01', '']
# ['172', '90042-MJP-G80', '152 24 90114-MGH-641 191 23 90231-MS2-610 155 17 90445-KE5-000 171 12 90650-MJP-G50 215 32 91053-MGS-D31', '']
# ['172', '90046-MJP-G50', '165 25 90115-KW7-900 251 21 90301-782-000 186 29 90450-KG8-000 219 13 90651-MA5-671 189 24 91059-KY2-711', '']
# ['172', '90047-MJP-G80', '165 26 90115-MJP-G50 228 12 90301-MG3-000 255 35 90451-155-000 173 15 192 28 91063-MZ1-003', '']
# ['172', '90048-MFL-000', '165 26 90115-MJP-G80 211 16 90301-MG8-000 240 12 174 24 90652-KT1-771 244 20 91070-GC4-601', '']
# ['172', '90050-MJP-G51', '155 16 90116-KW3-000 248 24 90302-435-761 198 9 90451-VM0-000 155 22 246 16 91071-MT7-003', '']
# ['172', '90065-MFG-D00', '228 11 90116-SP0-003 236 13 90302-MB1-000 193 12 90452-HL4-000 172 14 90652-MGS-D31 221 23 91071-MY1-005', '']
# ['172', '90071-MB0-000', '161 12 251 22 90303-HA0-680 219 12 90452-MAT-000 169 23 90656-MGH-641 230 26 91202-MAL-601', '']
# ['172', '91203-GC8-003', '', '']
# ['172', '91203-KK3-830', '', '']
# ['175', '91315-MGS-D20', '153 34 93913-255J0 221 28 95002-02100 253 25 96001-06025-00', '']
# ['175', '91205-KF0-003', '', '']
# ['175', '91207-MBB-003', '170 38 91315-MJP-G51 151 15 94000 95002-41000-08', '']
# ['172', '95002-41200-00', '', '']
# ['172', '91208-PF5-005', '210 16 180 1 94002-06000-0S 228 14 95002-50000 253 26 96001-06045-07', '']
# ['172', '91212-422-006', '206 23 91315-PC9-004 156 18 94002-08000-0S 206 26 95003-23016-60', '']
# ['208', '95003-23020-60', '', '']
# ['208', '91214-MAL-601', '233 26 91320-MB0-000 161 14 94050-04000 165 39 95005-35050-20 178 23 96100-63040-00', '']
# ['208', '91251-444-000', '228 13 91351-MGS-D30 213 32 94050-05000 240 16 95005-35080-20 178 24 96211-08000', '']
# ['208', '91252-MAS-003', '213 30 91352-MGE-003 163 22 94050-06000 190 27 95005-35110-20 178 25 96220-40080', '']
# ['208', '91253-MAE-003', '', '']
# ['208', '91254-KS6-003', '', '']
# ['208', '91254-KZ3-003', '', '']
# ['208', '91257-MAY-003', '204 20 91356-KZ3-003 199 22 94050-06070 237 23 208 33 96300-08025-08', '']
# ['208', '91262-KV3-831', '235 20 91456-MW3-600 195 32 238 15 95701-06012-08 186 37 96300-10020-08', '']
# ['208', '91301-GGL-J01', '178 18 91508-MM5-000 221 24 239 7 95701-06014-00 165 40 96300-10040-08', '']
# ['208', '91301-MEH-003', '154 14 91533-S82-003 195 33 94050-06080 246 18 168 30 96300-10060-08', '']
# ['165', '91533-SDA-003', '', '']
# ['180', '94050-08080', '', '']
# ['180', '91301-MJP-G81', '176 15 91565-SEL-003 244 23 94050-10080 248 30 173 19 96400-08035-04', '']
# ['180', '91301-MY9-003', '', '']
# ['252', '94101-08000', '', '']
# ['252', '91301-PLC-000', '', '']
# ['252', '91302-MAL-601', '', '']
# ['181', '94103-05700', '', '']
# ['181', '91302-PA9-003', '153 30 92101-06022-0A 222 8 94103-06000 182 7 95701-06016-00 150 16 96600-08028-10', '']
# ['156', '92900-08025-0B', '', '']
# ['181', '94103-06800', '', '']
# ['181', '91302-RGC-003', '', '']
# ['181', '94109-12000', '', '']
# ['181', '91303-377-000', '', '']
# ['180', '93404-06028-07', '', '']
# ['180', '91303-KF0-003', '163 19 93500-04008-1H 178 20 94201-20150 206 27 95701-06022-08 193 16 98200-42000', '']
# ['165', '93500-04012-0H', '', '']
# ['180', '93600-04012-1G', '', '']
# ['180', '91303-MJ0-003', '', '']
# ['180', '93600-04040-1G', '', '']
# ['180', '91304-HN8-003', '', '']
# ['4', '93892-05010-08', '', '']
# ['4', '91305-GE1-920', '', '']
# ['4', '91305-KC1-850', '', '']
# ['180', '93892-05035-18', '', '']
# ['180', '91305-KEH-601', '', '']
# ['180', '91305-MCJ-751', '', '']
# ['180', '95701-08025-07', '', '']
# ['180', '91307-035-000', '', '']
# ['180', '93901-22320', '', '']
# ['180', '91307-MGE-D01', '', '']
# ['181', '93901-32320', '', '']
# ['181', '91308-PY4-003', '156 17 93901-344G0 238 14 94303-04065 168 29 95701-08095-00', '']
# ['181', '93903-24280', '', '']
# ['181', '91309-425-003', '', '']
# ['180', '93903-25280', '', '']
# ['180', '91310-MGE-D01', '', '']
# ['165', '93903-25510', '', '']
# ['181', '93903-34310', '', '']
# ['181', '91311-RFH-003', '', '']

# %%
import re
import pdfplumber

def extract_section_with_layout(pdf_path: str, section_code: str, section_title: str):
    """
    Finds a specified section, locates 'Reqd. QTY', extracts in layout mode,
    then parses each part and variant into [REF_NO, PART_NO, DESCRIPTION, CATALOGUE_CODE].
    Stops collecting once it encounters any line containing 'PART', 'NO', and 'INDEX'.
    """
    code = section_code.upper()
    title = section_title.upper()

    next_sec_re     = re.compile(r'^[A-Z]+-\d+', re.IGNORECASE)
    table_header_re = re.compile(r'\bReqd\.?\s*QTY\b', re.IGNORECASE)
    part_no_re      = re.compile(r'\b[0-9]{5,}(?:-[A-Z0-9-]+)+\b')
    end_re          = re.compile(r'.*PART\s*NO\.?\s*INDEX.*', re.IGNORECASE)

    # Phase 1: locate page range
    start_page = header_hit = None
    end_page = None
    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages):
            for ln in (page.extract_text() or "").splitlines():
                u = ln.strip().upper()
                if start_page is None:
                    if (("FRAMEGROUP" in u and u.startswith(code) and title in u)
                        or (u.startswith(code) and title in u)):
                        start_page = i
                        break
                elif not header_hit:
                    if table_header_re.search(u):
                        header_hit = True
                else:
                    if next_sec_re.match(u) and not u.startswith(code):
                        end_page = i
                        break
            if end_page is not None:
                break
        if start_page is None or not header_hit:
            raise ValueError(f"Section '{section_code} {section_title}' not found or missing table header.")
        if end_page is None:
            end_page = len(pdf.pages)

        # Phase 2: collect layout-preserved lines
        collected = []
        in_table = False
        stop_all = False
        for pi in range(start_page, end_page):
            for ln in (pdf.pages[pi].extract_text(layout=True) or "").splitlines():
                u = ln.strip().upper()
                # if we see "PART ... NO ... INDEX" in any spacing, stop entirely
                if end_re.match(u):
                    stop_all = True
                    break
                if not in_table:
                    if table_header_re.search(u):
                        in_table = True
                    continue
                if next_sec_re.match(u) and not u.startswith(code):
                    break
                collected.append(ln)
            if stop_all:
                break

    # Phase 3: group into per-part buffers
    records = []
    last_ref = ""
    for ln in collected:
        m_pno = part_no_re.search(ln)
        if m_pno:
            m_ref = re.match(r'^\s*(?:\((\d+)\)|(\d+))\s+', ln)
            if m_ref:
                last_ref = m_ref.group(1) or m_ref.group(2)
            ref = last_ref
            pno = m_pno.group(0)
            buf = [ln[m_pno.end():].strip()]
            records.append({"ref": ref, "part_no": pno, "buf": buf})
        else:
            if not records:
                continue
            txt = ln.strip()
            if re.fullmatch(r'\d+', txt) or re.fullmatch(r'\d{4}\.\d{2}\.\d{2}', txt):
                continue
            records[-1]["buf"].append(txt)

    # Phase 4: parse each buffer
    out = []
    for rec in records:
        raw = " ".join(rec["buf"])
        raw = raw.replace('∙','').replace('•','').replace('\uf020','')
        raw = re.sub(r'\s+', ' ', raw).strip()

        idx = raw.find("--------")
        desc_part = raw[:idx].strip() if idx != -1 else raw
        cat_part  = raw[idx+8:].strip() if idx != -1 else ""

        desc_part = re.sub(r'\.{2,}\s+\d.*$', '', desc_part).strip()
        desc_part = re.sub(r'\s+GK[A-Za-z0-9]+\s*$', '', desc_part)
        desc_part = re.sub(r'\s+(?:-+|\d+)+\s*$', '', desc_part)
        desc = re.sub(r'\s+\d+\s+\d{4}\.\d{2}\.\d{2}.*$', "", desc_part).strip()
        desc = re.sub(r'(?:\s+(?:\(\d+\)|-+|\d+))+$', "", desc).strip()
        desc = re.sub(r'\.{2,}$', "", desc).strip()
        desc = re.sub(r'(?:\s+[A-Z])+$', '', desc).strip()
        desc = "" if not re.search(r'[A-Za-z]', desc) else desc

        if cat_part.upper().startswith("GK") and len(cat_part) > 8:
            cat_clean = cat_part[8:].split()[0]
        else:
            m_codes = re.match(r'[-\s]*([0-9A-Z,\s]+)', cat_part)
            raw_codes = m_codes.group(1) if m_codes else ""
            cat_clean = raw_codes.replace(" ", "")
            cat_clean = re.sub(r'([A-Z])(?=\d)', r'\1,', cat_clean)
            cat_clean = re.sub(
                r'(?<=[0-9A-Z]{2})(?=[A-Z]{2}(?:,|$))',
                ',',
                cat_clean
            )

        cat_clean = re.sub(r'\d{4}$', '', cat_clean)
        tokens = [t for t in cat_clean.split(',') if t]
        seen = set()
        final_codes = [c for c in tokens if c not in seen and not seen.add(c)]
        cat = ",".join(final_codes)

        m3 = re.match(r'^(.+?)([A-Z]{3,})$', rec["part_no"])
        if m3:
            core, suf = m3.group(1), m3.group(2)
            pno = core + suf[:2]
            desc = f"{suf[2:]} {desc}".strip()
        else:
            pno = rec["part_no"]

        out.append([rec["ref"], pno, desc, cat])

    return out

if __name__ == "__main__":
    pdf_file = "CRF1000 A_PC_13MJPG02_(G.H).pdf"
    for row in extract_section_with_layout(pdf_file, "F-40-2", "MARK/EMBLEM(CRF COLOR)"):
        print(row)
# Out:
# ['1', '86101-MJP-G50ZA', 'MARK , HONDA(65MM) *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U']
# ['2', '86102-MJP-G50ZA', 'MARK , HONDA(55MM) *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['3', '86171-MJP-F50ZA', 'STRIPE A, R. FUEL TANK *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['4', '86172-MJP-F50ZA', 'STRIPE A, L. FUEL TANK *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['5', '86173-MJP-F50ZA', 'STRIPE B, R. FUEL TANK *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['6', '86174-MJP-F50ZA', 'STRIPE B, L. FUEL TANK *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['7', '86211-MJP-G50', 'BADGE, R. PRODUCT', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['8', '86212-MJP-G50', 'BADGE, L. PRODUCT', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['9', '86611-MJP-F50ZA', 'STRIPE , R. FR. FENDER *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['10', '86612-MJP-F50ZA', 'STRIPE , L. FR. FENDER *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['11', '86641-MJP-F50ZA', 'STRIPE A, R. MIDDLE COWL *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['12', '86642-MJP-F50ZA', 'STRIPE A, L. MIDDLE COWL *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['13', '86643-MJP-F50ZA', 'STRIPE B, R. MIDDLE COWL *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['14', '86644-MJP-F50ZA', 'STRIPE B, L. MIDDLE COWL *TYPE1*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['15', '86831-MJP-G50ZA', 'MARK , R. SIDE COVER *TYPE3*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']
# ['16', '86832-MJP-G50ZA', 'MARK , L. SIDE COVER *TYPE3*', '3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH']

# %%
import re
import pandas as pd
import pdfplumber

def extract_section_with_layout(pdf_path: str, section_code: str, section_title: str):
    """
    Finds a specified section, locates 'Reqd. QTY', extracts in layout mode,
    then parses each part and variant into ref_no, part_no, description, remarks.
    Stops collecting once it encounters any line containing 'PART', 'NO', and 'INDEX'.
    Returns a DataFrame with columns ref_no, part_no, description, remarks.
    """
    code = section_code.upper()
    title = section_title.upper()

    next_sec_re     = re.compile(r'^[A-Z]+-\d+', re.IGNORECASE)
    table_header_re = re.compile(r'\bReqd\.?\s*QTY\b', re.IGNORECASE)
    part_no_re      = re.compile(r'\b[0-9]{5,}(?:-[A-Z0-9-]+)+\b')
    end_re          = re.compile(r'.*PART\s*NO\.?\s*INDEX.*', re.IGNORECASE)

    # Phase 1: locate page range
    start_page = header_hit = None
    end_page = None
    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages):
            for ln in (page.extract_text() or "").splitlines():
                u = ln.strip().upper()
                if start_page is None:
                    if (("FRAMEGROUP" in u and u.startswith(code) and title in u)
                        or (u.startswith(code) and title in u)):
                        start_page = i
                        break
                elif not header_hit:
                    if table_header_re.search(u):
                        header_hit = True
                else:
                    if next_sec_re.match(u) and not u.startswith(code):
                        end_page = i
                        break
            if end_page is not None:
                break
        if start_page is None or not header_hit:
            raise ValueError(f"Section '{section_code} {section_title}' not found or missing table header.")
        if end_page is None:
            end_page = len(pdf.pages)

        # Phase 2: collect layout-preserved lines
        collected = []
        in_table = False
        stop_all = False
        for pi in range(start_page, end_page):
            for ln in (pdf.pages[pi].extract_text(layout=True) or "").splitlines():
                u = ln.strip().upper()
                if end_re.match(u):
                    stop_all = True
                    break
                if not in_table:
                    if table_header_re.search(u):
                        in_table = True
                    continue
                if next_sec_re.match(u) and not u.startswith(code):
                    break
                collected.append(ln)
            if stop_all:
                break

    # Phase 3: group into per-part buffers
    records = []
    last_ref = ""
    for ln in collected:
        m_pno = part_no_re.search(ln)
        if m_pno:
            m_ref = re.match(r'^\s*(?:\((\d+)\)|(\d+))\s+', ln)
            if m_ref:
                last_ref = m_ref.group(1) or m_ref.group(2)
            records.append({
                "ref":      last_ref,
                "part_no":  m_pno.group(0),
                "buf":      [ln[m_pno.end():].strip()]
            })
        else:
            if not records:
                continue
            txt = ln.strip()
            if re.fullmatch(r'\d+', txt) or re.fullmatch(r'\d{4}\.\d{2}\.\d{2}', txt):
                continue
            records[-1]["buf"].append(txt)

    # Phase 4: parse each buffer directly into column-lists
    ref_nos      = []
    part_nos     = []
    descriptions = []
    remarks_list = []

    for rec in records:
        raw = " ".join(rec["buf"])
        raw = raw.replace('∙','').replace('•','').replace('\uf020','')
        raw = re.sub(r'\s+', ' ', raw).strip()

        idx       = raw.find("--------")
        desc_part = raw[:idx].strip() if idx != -1 else raw
        cat_part  = raw[idx+8:].strip() if idx != -1 else ""

        # clean up description
        desc_part = re.sub(r'\.{2,}\s+\d.*$', '', desc_part).strip()
        desc_part = re.sub(r'\s+GK[A-Za-z0-9]+\s*$', '', desc_part)
        desc_part = re.sub(r'\s+(?:-+|\d+)+\s*$', '', desc_part)
        desc      = re.sub(r'\s+\d+\s+\d{4}\.\d{2}\.\d{2}.*$', "", desc_part).strip()
        desc      = re.sub(r'(?:\s+(?:\(\d+\)|-+|\d+))+$',     "", desc).strip()
        desc      = re.sub(r'\.{2,}$',                         "", desc).strip()
        desc      = re.sub(r'(?:\s+[A-Z])+$',                  "", desc).strip()
        desc      = "" if not re.search(r'[A-Za-z]', desc) else desc

        # clean up catalogue codes → remarks
        if cat_part.upper().startswith("GK") and len(cat_part) > 8:
            cat_clean = cat_part[8:].split()[0]
        else:
            m_codes   = re.match(r'[-\s]*([0-9A-Z,\s]+)', cat_part)
            raw_codes = m_codes.group(1) if m_codes else ""
            cat_clean = raw_codes.replace(" ", "")
            cat_clean = re.sub(r'([A-Z])(?=\d)', r'\1,', cat_clean)
            cat_clean = re.sub(r'(?<=[0-9A-Z]{2})(?=[A-Z]{2}(?:,|$))', ',', cat_clean)
        cat_clean    = re.sub(r'\d{4}$', '', cat_clean)
        tokens       = [t for t in cat_clean.split(',') if t]
        seen         = set()
        final_codes  = [c for c in tokens if c not in seen and not seen.add(c)]
        remarks      = ",".join(final_codes)

        # adjust part_no suffix logic
        m3 = re.match(r'^(.+?)([A-Z]{3,})$', rec["part_no"])
        if m3:
            core, suf = m3.group(1), m3.group(2)
            part_no    = core + suf[:2]
            desc       = f"{suf[2:]} {desc}".strip()
        else:
            part_no = rec["part_no"]

        # append to column lists
        ref_nos.append(rec["ref"])
        part_nos.append(part_no)
        descriptions.append(desc)
        remarks_list.append(remarks)

    # build and return DataFrame
    df = pd.DataFrame({
        'ref_no':      ref_nos,
        'part_no':     part_nos,
        'description': descriptions,
        'remarks':     remarks_list
    })
    return df


if __name__ == "__main__":
    pdf_file = "NC750XAP_13MKWM02_PC_2022_2023.pdf"
    df = extract_section_with_layout(pdf_file, "F-50", "MARK")
    print(df.head(20))
# Out:
#    ref_no          part_no                   description          remarks
# 0       1    11378-MKS-E50                 PLATE, EMBLEM
# 1       2  86201-MKA-A30ZB  MARK, R. WING(105MM) *TYPE2*
# 2       2  86201-MKW-D00ZC                       *TYPE1*  2ED,CH,ED,FO,GS
# 3       2  86201-MKW-D00ZB                       *TYPE2*
# 4       2  86201-MKW-D00ZA                       *TYPE3*           2ED,ED
# 5       2  86201-MKW-D20ZB                       *TYPE2*           2ED,ED
# 6       2  86201-MKW-D20ZC                       *TYPE1*
# 7       2  86201-MKW-D20ZA                       *TYPE3*        2ED,ED,GS
# 8       3  86202-MKA-A30ZB  MARK, L. WING(105MM) *TYPE2*
# 9       3  86202-MKW-D00ZC                       *TYPE1*  2ED,CH,ED,FO,GS
# 10      3  86202-MKW-D00ZB                       *TYPE2*
# 11      3  86202-MKW-D00ZA                       *TYPE3*           2ED,ED
# 12      3  86202-MKW-D20ZB                       *TYPE2*           2ED,ED
# 13      3  86202-MKW-D20ZC                       *TYPE1*
# 14      3  86202-MKW-D20ZA                       *TYPE3*        2ED,ED,GS
# 15      4  86611-MJF-A00ZA             MARK, ABS *TYPE2*
# 16      4  86611-MJF-A00ZB                       *TYPE1*

# %%
import re
import pandas as pd
import pdfplumber

def extract_section_with_layout(pdf_path: str, section_code: str, section_title: str) -> pd.DataFrame:
    """
    Finds a specified section, locates 'Reqd. QTY', extracts in layout mode,
    then parses each part and variant into ref_no, part_no, description, remarks.
    Stops collecting once it encounters any line containing 'PART', 'NO', and 'INDEX'.
    Returns a DataFrame with columns ref_no, part_no, description, remarks.
    """
    code = section_code.upper()
    title = section_title.upper()

    next_sec_re     = re.compile(r'^[A-Z]+-\d+', re.IGNORECASE)
    table_header_re = re.compile(r'\bReqd\.?\s*QTY\b', re.IGNORECASE)
    part_no_re      = re.compile(r'\b[0-9]{5,}(?:-[A-Z0-9-]+)+\b')
    end_re          = re.compile(r'.*PART\s*NO\.?\s*INDEX.*', re.IGNORECASE)

    # Phase 1: locate page range
    start_page = header_hit = None
    end_page = None
    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages):
            for ln in (page.extract_text() or "").splitlines():
                u = ln.strip().upper()
                if start_page is None:
                    if (("FRAMEGROUP" in u and u.startswith(code) and title in u)
                        or (u.startswith(code) and title in u)):
                        start_page = i
                        break
                elif not header_hit:
                    if table_header_re.search(u):
                        header_hit = True
                else:
                    if next_sec_re.match(u) and not u.startswith(code):
                        end_page = i
                        break
            if end_page is not None:
                break
        if start_page is None or not header_hit:
            raise ValueError(f"Section '{section_code} {section_title}' not found or missing table header.")
        if end_page is None:
            end_page = len(pdf.pages)

        # Phase 2: collect layout-preserved lines
        collected = []
        in_table = False
        stop_all = False
        for pi in range(start_page, end_page):
            for ln in (pdf.pages[pi].extract_text(layout=True) or "").splitlines():
                u = ln.strip().upper()
                if end_re.match(u):
                    stop_all = True
                    break
                if not in_table:
                    if table_header_re.search(u):
                        in_table = True
                    continue
                if next_sec_re.match(u) and not u.startswith(code):
                    break
                collected.append(ln)
            if stop_all:
                break

    # Phase 3: group into per-part buffers
    records = []
    last_ref = ""
    for ln in collected:
        m_pno = part_no_re.search(ln)
        if m_pno:
            m_ref = re.match(r'^\s*(?:\((\d+)\)|(\d+))\s+', ln)
            if m_ref:
                last_ref = m_ref.group(1) or m_ref.group(2)
            records.append({
                "ref":      last_ref,
                "part_no":  m_pno.group(0),
                "buf":      [ln[m_pno.end():].strip()]
            })
        else:
            if not records:
                continue
            txt = ln.strip()
            if re.fullmatch(r'\d+', txt) or re.fullmatch(r'\d{4}\.\d{2}\.\d{2}', txt):
                continue
            records[-1]["buf"].append(txt)

    # Phase 4: parse each buffer directly into column-lists
    ref_nos      = []
    part_nos     = []
    descriptions = []
    remarks_list = []

    for rec in records:
        raw = " ".join(rec["buf"])
        raw = raw.replace('∙','').replace('•','').replace('\uf020','')
        raw = re.sub(r'\s+', ' ', raw).strip()

        idx       = raw.find("--------")
        desc_part = raw[:idx].strip() if idx != -1 else raw
        cat_part  = raw[idx+8:].strip() if idx != -1 else ""

        # clean up description
        desc_part = re.sub(r'\.{2,}\s+\d.*$', '', desc_part).strip()
        desc_part = re.sub(r'\s+GK[A-Za-z0-9]+\s*$', '', desc_part)
        desc_part = re.sub(r'\s+(?:-+|\d+)+\s*$', '', desc_part)
        desc      = re.sub(r'\s+\d+\s+\d{4}\.\d{2}\.\d{2}.*$', "", desc_part).strip()
        desc      = re.sub(r'(?:\s+(?:\(\d+\)|-+|\d+))+$',     "", desc).strip()
        desc      = re.sub(r'\.{2,}$',                         "", desc).strip()
        desc      = re.sub(r'(?:\s+[A-Z])+$',                  "", desc).strip()
        desc      = "" if not re.search(r'[A-Za-z]', desc) else desc

        # clean up catalogue codes → remarks
        if cat_part.upper().startswith("GK") and len(cat_part) > 8:
            cat_clean = cat_part[8:].split()[0]
        else:
            m_codes   = re.match(r'[-\s]*([0-9A-Z,\s]+)', cat_part)
            raw_codes = m_codes.group(1) if m_codes else ""
            cat_clean = raw_codes.replace(" ", "")
            cat_clean = re.sub(r'([A-Z])(?=\d)', r'\1,', cat_clean)
            cat_clean = re.sub(r'(?<=[0-9A-Z]{2})(?=[A-Z]{2}(?:,|$))', ',', cat_clean)
        cat_clean    = re.sub(r'\d{4}$', '', cat_clean)
        tokens       = [t for t in cat_clean.split(',') if t]
        seen         = set()
        final_codes  = [c for c in tokens if c not in seen and not seen.add(c)]
        remarks      = ",".join(final_codes)

        # adjust part_no suffix logic
        m3 = re.match(r'^(.+?)([A-Z]{3,})$', rec["part_no"])
        if m3:
            core, suf = m3.group(1), m3.group(2)
            part_no    = core + suf[:2]
            desc       = f"{suf[2:]} {desc}".strip()
        else:
            part_no = rec["part_no"]

        ref_nos.append(rec["ref"])
        part_nos.append(part_no)
        descriptions.append(desc)
        remarks_list.append(remarks)

    df = pd.DataFrame({
        'ref_no':      ref_nos,
        'part_no':     part_nos,
        'description': descriptions,
        'remarks':     remarks_list
    })
    return df


def extract_all_sections_one_pass(pdf_path: str, output_csv: str) -> pd.DataFrame:
    """
    Opens the PDF once, walks through it page by page, detects sections using
    next_sec_re, collects each section’s lines, inlines Phase 3+4 verbatim,
    stops entirely when end_re is first encountered, strips any leading
    "*GROUP" from titles, and writes a CSV with columns
    section_no, section_name, ref_no, part_no, description, remarks.
    """
    next_sec_re     = re.compile(r'^[A-Z]+-\d+', re.IGNORECASE)
    table_header_re = re.compile(r'\bReqd\.?\s*QTY\b', re.IGNORECASE)
    part_no_re      = re.compile(r'\b[0-9]{5,}(?:-[A-Z0-9-]+)+\b')
    end_re          = re.compile(r'.*PART\s*NO\.?\s*INDEX.*', re.IGNORECASE)

    section_nos   = []
    section_names = []
    ref_nos       = []
    part_nos      = []
    descriptions  = []
    remarks_list  = []

    current = None
    done    = False

    def _flush(cur):
        """Phase 3+4 logic verbatim, flushing cur['collected'] into our lists."""
        records = []; last_ref = ""
        for ln in cur['collected']:
            m_pno = part_no_re.search(ln)
            if m_pno:
                m_ref = re.match(r'^\s*(?:\((\d+)\)|(\d+))\s+', ln)
                if m_ref:
                    last_ref = m_ref.group(1) or m_ref.group(2)
                records.append({
                    'ref': last_ref,
                    'part_no': m_pno.group(0),
                    'buf': [ln[m_pno.end():].strip()]
                })
            else:
                if not records: continue
                txt = ln.strip()
                if re.fullmatch(r'\d+', txt) or re.fullmatch(r'\d{4}\.\d{2}\.\d{2}', txt):
                    continue
                records[-1]['buf'].append(txt)

        for rec in records:
            raw = " ".join(rec['buf']).replace('∙','').replace('•','').replace('\uf020','')
            raw = re.sub(r'\s+', ' ', raw).strip()
            idx = raw.find("--------")
            desc_part = raw[:idx].strip() if idx != -1 else raw
            cat_part  = raw[idx+8:].strip() if idx != -1 else ""

            # description cleanup
            desc_part = re.sub(r'\.{2,}\s+\d.*$', '', desc_part).strip()
            desc_part = re.sub(r'\s+GK[A-Za-z0-9]+\s*$', '', desc_part)
            desc_part = re.sub(r'\s+(?:-+|\d+)+\s*$', '', desc_part)
            desc = re.sub(r'\s+\d+\s+\d{4}\.\d{2}\.\d{2}.*$', "", desc_part).strip()
            desc = re.sub(r'(?:\s+(?:\(\d+\)|-+|\d+))+$', "", desc).strip()
            desc = re.sub(r'\.{2,}$', "", desc).strip()
            desc = re.sub(r'(?:\s+[A-Z])+$', "", desc).strip()
            desc = "" if not re.search(r'[A-Za-z]', desc) else desc

            # remarks cleanup
            if cat_part.upper().startswith("GK") and len(cat_part) > 8:
                cat_clean = cat_part[8:].split()[0]
            else:
                m_codes   = re.match(r'[-\s]*([0-9A-Z,\s]+)', cat_part)
                raw_codes = m_codes.group(1) if m_codes else ""
                cat_clean = raw_codes.replace(" ", "")
                cat_clean = re.sub(r'([A-Z])(?=\d)', r'\1,', cat_clean)
                cat_clean = re.sub(r'(?<=[0-9A-Z]{2})(?=[A-Z]{2}(?:,|$))', ',', cat_clean)
            cat_clean   = re.sub(r'\d{4}$', '', cat_clean)
            tokens      = [t for t in cat_clean.split(',') if t]
            seen        = set()
            final_codes = [c for c in tokens if c not in seen and not seen.add(c)]
            remarks     = ",".join(final_codes)

            m3 = re.match(r'^(.+?)([A-Z]{3,})$', rec['part_no'])
            if m3:
                core, suf = m3.group(1), m3.group(2)
                pno        = core + suf[:2]
                desc       = f"{suf[2:]} {desc}".strip()
            else:
                pno = rec['part_no']

            section_nos.append(cur['code'])
            section_names.append(cur['title'])
            ref_nos.append(rec['ref'])
            part_nos.append(pno)
            descriptions.append(desc)
            remarks_list.append(remarks)

    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            if done:
                break

            plain  = (page.extract_text() or "").splitlines()
            layout = (page.extract_text(layout=True) or "").splitlines()

            # detect new section headers
            for ln in plain:
                if done:
                    break
                u = ln.strip().upper()
                if next_sec_re.match(u):
                    if current:
                        _flush(current)
                    parts = ln.strip().split(None, 1)
                    raw_title = parts[1].strip() if len(parts) > 1 else ""
                    # strip any leading "*GROUP"
                    title = re.sub(r'\b[A-Z]+GROUP\b\s*', '', raw_title, flags=re.IGNORECASE)
                    current = {
                        'code':       parts[0].upper(),
                        'title':      title,
                        'header_hit': False,
                        'collected':  []
                    }

            # collect layout lines
            if current:
                for ln in layout:
                    u = ln.strip().upper()
                    if end_re.match(u):
                        _flush(current)
                        done = True
                        break
                    if not current['header_hit']:
                        if table_header_re.search(u):
                            current['header_hit'] = True
                        continue
                    if next_sec_re.match(u) and not u.startswith(current['code']):
                        _flush(current)
                        current = None
                        break
                    current['collected'].append(ln)

    if current and not done:
        _flush(current)

    final_df = pd.DataFrame({
        'section_no':   section_nos,
        'section_name': section_names,
        'ref_no':       ref_nos,
        'part_no':      part_nos,
        'description':  descriptions,
        'remarks':      remarks_list
    })
    final_df.to_csv(output_csv, index=False)
    return final_df


if __name__ == "__main__":
    pdf_file = "Manuals/CRF1000 A_PC_13MJPG02_(G.H).pdf"
    df = extract_all_sections_one_pass(pdf_file, "all_sections2.csv")

# %%
# Modified by me
import re
import pandas as pd
import pdfplumber

def extract_section_with_layout(pdf_path: str, section_code: str, section_title: str) -> pd.DataFrame:
    """
    Finds a specified section, locates 'Reqd. QTY', extracts in layout mode,
    then parses each part and variant into ref_no, part_no, description, remarks.
    Stops collecting once it encounters any line containing 'PART', 'NO', and 'INDEX'.
    Returns a DataFrame with columns ref_no, part_no, description, remarks.
    """
    code = section_code.upper()
    title = section_title.upper()

    next_sec_re     = re.compile(r'^[A-Z]+-\d+', re.IGNORECASE)
    table_header_re = re.compile(r'\bReqd\.?\s*QTY\b', re.IGNORECASE)
    part_no_re      = re.compile(r'\b[0-9]{5,}(?:-[A-Z0-9-]+)+\b')
    end_re          = re.compile(r'.*PART\s*NO\.?\s*INDEX.*', re.IGNORECASE)

    # Phase 1: locate page range
    start_page = header_hit = None
    end_page = None
    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages):
            for ln in (page.extract_text() or "").splitlines():
                u = ln.strip().upper()
                if start_page is None:
                    if (("FRAMEGROUP" in u and u.startswith(code) and title in u)
                        or (u.startswith(code) and title in u)):
                        start_page = i
                        break
                elif not header_hit:
                    if table_header_re.search(u):
                        header_hit = True
                else:
                    if next_sec_re.match(u) and not u.startswith(code):
                        end_page = i
                        break
            if end_page is not None:
                break
        if start_page is None or not header_hit:
            raise ValueError(f"Section '{section_code} {section_title}' not found or missing table header.")
        if end_page is None:
            end_page = len(pdf.pages)

        # Phase 2: collect layout-preserved lines
        collected = []
        in_table = False
        stop_all = False
        for pi in range(start_page, end_page):
            for ln in (pdf.pages[pi].extract_text(layout=True) or "").splitlines():
                u = ln.strip().upper()
                if end_re.match(u):
                    stop_all = True
                    break
                if not in_table:
                    if table_header_re.search(u):
                        in_table = True
                    continue
                if next_sec_re.match(u) and not u.startswith(code):
                    break
                collected.append(ln)
            if stop_all:
                break

    # Phase 3: group into per-part buffers
    records = []
    last_ref = ""
    for ln in collected:
        m_pno = part_no_re.search(ln)
        if m_pno:
            m_ref = re.match(r'^\s*(?:\((\d+)\)|(\d+))\s+', ln)
            if m_ref:
                last_ref = m_ref.group(1) or m_ref.group(2)
            records.append({
                "ref":      last_ref,
                "part_no":  m_pno.group(0),
                "buf":      [ln[m_pno.end():].strip()]
            })
        else:
            if not records:
                continue
            txt = ln.strip()
            if re.fullmatch(r'\d+', txt) or re.fullmatch(r'\d{4}\.\d{2}\.\d{2}', txt):
                continue
            records[-1]["buf"].append(txt)

    # Phase 4: parse each buffer directly into column-lists
    ref_nos      = []
    part_nos     = []
    descriptions = []
    remarks_list = []

    for rec in records:
        raw = " ".join(rec["buf"])
        raw = raw.replace('∙','').replace('•','').replace('\uf020','')
        raw = re.sub(r'\s+', ' ', raw).strip()

        idx       = raw.find("--------")
        desc_part = raw[:idx].strip() if idx != -1 else raw
        cat_part  = raw[idx+8:].strip() if idx != -1 else ""

        # clean up description
        desc_part = re.sub(r'\.{2,}\s+\d.*$', '', desc_part).strip()
        desc_part = re.sub(r'\s+GK[A-Za-z0-9]+\s*$', '', desc_part)
        desc_part = re.sub(r'\s+(?:-+|\d+)+\s*$', '', desc_part)
        desc      = re.sub(r'\s+\d+\s+\d{4}\.\d{2}\.\d{2}.*$', "", desc_part).strip()
        desc      = re.sub(r'(?:\s+(?:\(\d+\)|-+|\d+))+$',     "", desc).strip()
        desc      = re.sub(r'\.{2,}$',                         "", desc).strip()
        desc      = re.sub(r'(?:\s+[A-Z])+$',                  "", desc).strip()
        desc      = "" if not re.search(r'[A-Za-z]', desc) else desc

        # clean up catalogue codes → remarks
        if cat_part.upper().startswith("GK") and len(cat_part) > 8:
            cat_clean = cat_part[8:].split()[0]
        else:
            m_codes   = re.match(r'[-\s]*([0-9A-Z,\s]+)', cat_part)
            raw_codes = m_codes.group(1) if m_codes else ""
            cat_clean = raw_codes.replace(" ", "")
            cat_clean = re.sub(r'([A-Z])(?=\d)', r'\1,', cat_clean)
            cat_clean = re.sub(r'(?<=[0-9A-Z]{2})(?=[A-Z]{2}(?:,|$))', ',', cat_clean)
        cat_clean    = re.sub(r'\d{4}$', '', cat_clean)
        tokens       = [t for t in cat_clean.split(',') if t]
        seen         = set()
        final_codes  = [c for c in tokens if c not in seen and not seen.add(c)]
        remarks      = ",".join(final_codes)

        # adjust part_no suffix logic
        m3 = re.match(r'^(.+?)([A-Z]{3,})$', rec["part_no"])
        if m3:
            core, suf = m3.group(1), m3.group(2)
            part_no    = core + suf[:2]
            desc       = f"{suf[2:]} {desc}".strip()
        else:
            part_no = rec["part_no"]

        ref_nos.append(rec["ref"])
        part_nos.append(part_no)
        descriptions.append(desc)
        remarks_list.append(remarks)

    df = pd.DataFrame({
        'ref_no':      ref_nos,
        'part_no':     part_nos,
        'description': descriptions,
        'remarks':     remarks_list
    })
    return df

def extract_all_sections_one_pass(pdf_id, year, brand, model, batch_id, pdf_path: str) -> pd.DataFrame:
    """
    Opens the PDF once, walks through it page by page, detects sections using
    next_sec_re, collects each section’s lines, inlines Phase 3+4 verbatim,
    stops entirely when end_re is first encountered, strips any leading
    "*GROUP" from titles, and writes a CSV with columns
    section_no, section_name, ref_no, part_no, description, remarks.
    """
    next_sec_re     = re.compile(r'^[A-Z]+-\d+', re.IGNORECASE)
    table_header_re = re.compile(r'\bReqd\.?\s*QTY\b', re.IGNORECASE)
    part_no_re      = re.compile(r'\b[0-9]{5,}(?:-[A-Z0-9-]+)+\b')
    end_re          = re.compile(r'.*PART\s*NO\.?\s*INDEX.*', re.IGNORECASE)

    section_nos   = []
    section_names = []
    ref_nos       = []
    part_nos      = []
    descriptions  = []
    remarks_list  = []

    current = None
    done    = False

    def _flush(cur):
        """Phase 3+4 logic verbatim, flushing cur['collected'] into our lists."""
        records = []; last_ref = ""
        for ln in cur['collected']:
            m_pno = part_no_re.search(ln)
            if m_pno:
                m_ref = re.match(r'^\s*(?:\((\d+)\)|(\d+))\s+', ln)
                if m_ref:
                    last_ref = m_ref.group(1) or m_ref.group(2)
                records.append({
                    'ref': last_ref,
                    'part_no': m_pno.group(0),
                    'buf': [ln[m_pno.end():].strip()]
                })
            else:
                if not records: continue
                txt = ln.strip()
                if re.fullmatch(r'\d+', txt) or re.fullmatch(r'\d{4}\.\d{2}\.\d{2}', txt):
                    continue
                records[-1]['buf'].append(txt)

        for rec in records:
            raw = " ".join(rec['buf']).replace('∙','').replace('•','').replace('\uf020','')
            raw = re.sub(r'\s+', ' ', raw).strip()
            idx = raw.find("--------")
            desc_part = raw[:idx].strip() if idx != -1 else raw
            cat_part  = raw[idx+8:].strip() if idx != -1 else ""

            # description cleanup
            desc_part = re.sub(r'\.{2,}\s+\d.*$', '', desc_part).strip()
            desc_part = re.sub(r'\s+GK[A-Za-z0-9]+\s*$', '', desc_part)
            desc_part = re.sub(r'\s+(?:-+|\d+)+\s*$', '', desc_part)
            desc = re.sub(r'\s+\d+\s+\d{4}\.\d{2}\.\d{2}.*$', "", desc_part).strip()
            desc = re.sub(r'(?:\s+(?:\(\d+\)|-+|\d+))+$', "", desc).strip()
            desc = re.sub(r'\.{2,}$', "", desc).strip()
            desc = re.sub(r'(?:\s+[A-Z])+$', "", desc).strip()
            desc = "" if not re.search(r'[A-Za-z]', desc) else desc

            # remarks cleanup
            if cat_part.upper().startswith("GK") and len(cat_part) > 8:
                cat_clean = cat_part[8:].split()[0]
            else:
                m_codes   = re.match(r'[-\s]*([0-9A-Z,\s]+)', cat_part)
                raw_codes = m_codes.group(1) if m_codes else ""
                cat_clean = raw_codes.replace(" ", "")
                cat_clean = re.sub(r'([A-Z])(?=\d)', r'\1,', cat_clean)
                cat_clean = re.sub(r'(?<=[0-9A-Z]{2})(?=[A-Z]{2}(?:,|$))', ',', cat_clean)
            cat_clean   = re.sub(r'\d{4}$', '', cat_clean)
            tokens      = [t for t in cat_clean.split(',') if t]
            seen        = set()
            final_codes = [c for c in tokens if c not in seen and not seen.add(c)]
            remarks     = ",".join(final_codes)

            m3 = re.match(r'^(.+?)([A-Z]{3,})$', rec['part_no'])
            if m3:
                core, suf = m3.group(1), m3.group(2)
                pno        = core + suf[:2]
                desc       = f"{suf[2:]} {desc}".strip()
            else:
                pno = rec['part_no']

            section_nos.append(cur['code'])
            section_names.append(cur['title'])
            ref_nos.append(rec['ref'])
            part_nos.append(pno)
            descriptions.append(desc)
            remarks_list.append(remarks)

    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            if done:
                break

            plain  = (page.extract_text() or "").splitlines()
            layout = (page.extract_text(layout=True) or "").splitlines()

            # detect new section headers
            for ln in plain:
                if done:
                    break
                u = ln.strip().upper()
                if next_sec_re.match(u):
                    if current:
                        _flush(current)
                    parts = ln.strip().split(None, 1)
                    raw_title = parts[1].strip() if len(parts) > 1 else ""
                    # strip any leading "*GROUP"
                    title = re.sub(r'\b[A-Z]+GROUP\b\s*', '', raw_title, flags=re.IGNORECASE)
                    current = {
                        'code':       parts[0].upper(),
                        'title':      title,
                        'header_hit': False,
                        'collected':  []
                    }

            # collect layout lines
            if current:
                for ln in layout:
                    u = ln.strip().upper()
                    if end_re.match(u):
                        _flush(current)
                        done = True
                        break
                    if not current['header_hit']:
                        if table_header_re.search(u):
                            current['header_hit'] = True
                        continue
                    if next_sec_re.match(u) and not u.startswith(current['code']):
                        _flush(current)
                        current = None
                        break
                    current['collected'].append(ln)

    if current and not done:
        _flush(current)

    final_df = pd.DataFrame({
        'pdf_id': pdf_id,       #added
        'year': year,           #added
        'brand': brand,         #added
        'model': model,         #added
        'batch_id': batch_id,   #added
        'section_no':   section_nos,
        'section_name': section_names,
        'ref_no':       ref_nos,
        'part_no':      part_nos,
        'description':  descriptions,
        'remarks':      remarks_list
    })
    return final_df

if __name__ == "__main__":
    pdf_file = "Manuals/CRF1000 A_PC_13MJPG02_(G.H).pdf"
    df = extract_all_sections_one_pass("CRF1000_13MJPG02", "2022", "Honda", "CRF1000", "13MJPG02", pdf_file)
    print(df.to_string(index=False))
# Out:
#           pdf_id year brand   model batch_id section_no                                  section_name ref_no         part_no                                                        description                                                                remarks
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-1                           CYLINDER HEAD COVER      1   12229-HL4-000                                                    SEAL, PLUG TUBE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-1                           CYLINDER HEAD COVER      2   12300-MJP-G50                                         COVER ASSY., CYLINDER HEAD
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-1                           CYLINDER HEAD COVER      3   12341-MAT-750                                                    PLATE, PORT(AI)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-1                           CYLINDER HEAD COVER      4   12391-HL4-000                                                 GASKET, HEAD COVER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-1                           CYLINDER HEAD COVER      5   18601-KEA-741                                            VALVE COMP., REED(ARAI)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-1                           CYLINDER HEAD COVER      6   18612-MJP-G50                                                  COVER, REED VALVE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-1                           CYLINDER HEAD COVER      7   90004-GHB-640                                           BOLT, FLANGE, 6X18(NSHF)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-1                           CYLINDER HEAD COVER      8   90017-MAL-600                                                   BOLT, HEAD COVER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-1                           CYLINDER HEAD COVER      9   90543-MV9-670                                                   RUBBER, MOUNTING
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-1                           CYLINDER HEAD COVER     10     94301-10160                                                   DOWEL PIN, 10X16
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD      1   12010-MJP-G50                                               HEAD ASSY., CYLINDER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD      2   12204-HL4-305                                             GUIDE, IN. VALVE(O.S.)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD      3   12205-HL4-305                                             GUIDE, EX. VALVE(O.S.)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD      4   12251-MJP-G51                                              GASKET, CYLINDER HEAD
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD      5   16211-MJP-G50                                           INSULATOR, THROTTLE BODY
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD      6   16218-MCA-000                                                    BAND, INSULATOR
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD      7   16218-MJP-G50                                                    BAND, INSULATOR
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD      8   19300-MCJ-003                                                         THERMOSTAT
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD      9   19305-KV3-010                                                 RUBBER, THERMOSTAT
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD     10   19321-MJP-G50                                                  COVER, THERMOSTAT
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD     11   31909-MJP-G51                                       PLUG, SPARK(SILMAR8A9S)(NGK)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD     12   37870-MGS-D31                                    SENSOR ASSY., WATER TEMPERATURE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD     13   90001-MGZ-J00                                          BOLT, FLANGE SOCKET, 6X22
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD     14   90006-GHB-710                                           BOLT, FLANGE, 6X40(NSHF)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD     15   90007-HL4-003                                                BOLT-WASHER, 12X118
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD     16   90017-MA6-000                                               BOLT, FLANGE, 6X45.5
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD     17   90032-MJP-G50                                                BOLT, SEALING, 14MM
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD     18   90544-KF0-000                                              WASHER, SEALING, 14MM
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD     19  92900-08025-0B                                                   BOLT, STUD, 8X25
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD     20     94301-08200                                                    DOWEL PIN, 8X20
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-2                                 CYLINDER HEAD     21     94301-14200                                                   DOWEL PIN, 14X20
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE      1   12208-MEG-003                                             SEAL, VALVE STEM(ARAI)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE      2   12208-413-003                                             SEAL, VALVE STEM(ARAI)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE      3   14110-MJP-G50                                                     CAMSHAFT COMP.
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE      4   14410-HL4-000                                            ARM COMP. A, EX. ROCKER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE      5   14420-HL4-000                                            ARM COMP. B, EX. ROCKER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE      6   14451-HL4-000                                                  SHAFT, ROCKER ARM
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE      7   14711-HL4-000                                                         VALVE, IN.
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE      8   14721-MJP-G50                                                         VALVE, EX.
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE      9   14731-MGE-010                                                      LIFTER, VALVE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     10   14751-MJP-G50                                                      SPRING, VALVE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     11   14771-HL4-000                                             RETAINER, VALVE SPRING
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     12   14775-MJP-G50                                                 SEAT, VALVE SPRING
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     13   14781-HA0-770                                                      COTTER, VALVE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14901-MBB-000                                                 SHIM, TAPPET(1.20)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14902-MBB-000                                                SHIM, TAPPET(1.225)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14903-MBB-000                                                SHIM, TAPPET(1.250)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14904-MBB-000                                                SHIM, TAPPET(1.275)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14905-MBB-000                                                 SHIM, TAPPET(1.30)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14906-MBB-000                                                SHIM, TAPPET(1.325)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14907-MBB-000                                                SHIM, TAPPET(1.350)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14908-MBB-000                                                SHIM, TAPPET(1.375)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14909-MBB-000                                                 SHIM, TAPPET(1.40)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14910-MBB-000                                                SHIM, TAPPET(1.425)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14911-MBB-000                                                SHIM, TAPPET(1.450)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14912-MBB-000                                                SHIM, TAPPET(1.475)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14913-MBB-000                                                 SHIM, TAPPET(1.50)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     14   14914-MBB-000                                                SHIM, TAPPET(1.525)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14915-MBB-000                                                SHIM, TAPPET(1.550)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14916-MBB-000                                                SHIM, TAPPET(1.575)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14917-MBB-000                                                 SHIM, TAPPET(1.60)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14918-MBB-000                                                SHIM, TAPPET(1.625)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14919-MBB-000                                                SHIM, TAPPET(1.650)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14920-MBB-000                                                SHIM, TAPPET(1.675)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14921-MBB-000                                                 SHIM, TAPPET(1.70)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14922-MBB-000                                                SHIM, TAPPET(1.725)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14923-MBB-000                                                SHIM, TAPPET(1.750)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14924-MBB-000                                                SHIM, TAPPET(1.775)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14925-MBB-000                                                 SHIM, TAPPET(1.80)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14926-MBB-000                                                SHIM, TAPPET(1.825)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14927-MBB-000                                                SHIM, TAPPET(1.850)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14928-MBB-000                                                SHIM, TAPPET(1.875)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14929-MBB-000                                                 SHIM, TAPPET(1.90)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14930-MBB-000                                                SHIM, TAPPET(1.925)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14931-MBB-000                                                SHIM, TAPPET(1.950)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14932-MBB-000                                                SHIM, TAPPET(1.975)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14933-MBB-000                                                 SHIM, TAPPET(2.00)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14934-MBB-000                                                SHIM, TAPPET(2.025)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14935-MBB-000                                                SHIM, TAPPET(2.050)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14936-MBB-000                                                SHIM, TAPPET(2.075)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14937-MBB-000                                                 SHIM, TAPPET(2.10)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14938-MBB-000                                                SHIM, TAPPET(2.125)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14939-MBB-000                                                SHIM, TAPPET(2.150)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14940-MBB-000                                                SHIM, TAPPET(2.175)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14941-MBB-000                                                 SHIM, TAPPET(2.20)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14942-MBB-000                                                SHIM, TAPPET(2.225)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14943-MBB-000                                                SHIM, TAPPET(2.250)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14944-MBB-000                                                SHIM, TAPPET(2.275)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14945-MBB-000                                                 SHIM, TAPPET(2.30)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14946-MBB-000                                                SHIM, TAPPET(2.325)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14947-MBB-000                                                SHIM, TAPPET(2.350)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14948-MBB-000                                                SHIM, TAPPET(2.375)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14949-MBB-000                                                 SHIM, TAPPET(2.40)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14950-MBB-000                                                SHIM, TAPPET(2.425)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE          14951-MBB-000                                                SHIM, TAPPET(2.450)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     15   90012-MGE-000                                            SCREW, TAPPET ADJUSTING
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     16   90206-KM3-000                                              NUT, TAPPET ADJUSTING
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-3                                CAMSHAFT/VALVE     17  95701-06030-00                                                 BOLT, FLANGE, 6X30
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER      1   14311-MJP-G50                                              SPROCKET, TIMING(19T)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER      2   14321-MJP-G50                                                 SPROCKET, CAM(38T)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER      3   14401-MJP-G51                                      CHAIN, CAM(128L)(BORG WARNER)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER      4   14510-MJP-G50                                         TENSIONER COMP., CAM CHAIN
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER      5   14520-MJP-G51                                            LIFTER ASSY., TENSIONER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER      6   14523-HL4-003                                             GASKET, TENSIONER HOLE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER      7   14524-MBB-000                                                    CAP, LIFTER PAT
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER      8   14611-MJP-G50                                                 GUIDE A, CAM CHAIN
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER      9   14612-MJP-G50                                             PLATE, CAM CHAIN GUIDE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER     10   90004-GHB-600                                           BOLT, FLANGE, 6X10(NSHF)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER     11   90008-MJP-G50                                                 BOLT, SPECIAL, 8MM
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER     12   90010-GHB-670                                                 BOLT, FLANGE, 6X25
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER     13   90082-HA0-000                                         BOLT, FLANGE KNOCK, 7X10.5
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER     14   90442-397-000                                               WASHER, SEALING, 6MM
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER     15   90505-425-000                                                        WASHER, 8MM
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-4                           CAM CHAIN/TENSIONER     16  95701-06016-00                                                 BOLT, FLANGE, 6X16
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)      1   11330-MJP-G50                                          COVER COMP., R. CRANKCASE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)      2   11376-MJP-G50                                               COVER, R. RR. ENGINE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)      3   11385-MJF-A00                                                             COLLAR
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)      4   11394-MJP-G51                                         GASKET, R. CRANKCASE COVER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)      5   19200-MJP-G50                                                  PUMP COMP., WATER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)      6   19226-MJP-G50                                            GASKET, WATER PUMP BODY
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)      7   22810-MJP-G50                                                LEVER COMP., CLUTCH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)      8   22815-413-000                                               SPRING, CLUTCH LEVER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)      9   22821-MJP-G50                                             RECEIVER, CLUTCH CABLE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)     10   90004-MJP-G50                                          BOLT, FLANGE SOCKET, 6X28
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)     11   90085-MGC-920                                                BOLT, SPECIAL, 6X17
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)     12   90488-425-000                                               WASHER, SEALING, 6MM
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)     13   91053-MFJ-D01                                          BEARING, NEEDLE, 12X16X10
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)     14   91205-KF0-003                                            OIL SEAL, 12X20X5(ARAI)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)     15   91315-MJP-G51                                                   SEAL, WATER PIPE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)     16     94301-06100                                                    DOWEL PIN, 6X10
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)     17     94301-08140                                                    DOWEL PIN, 8X14
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)     18  95701-06016-00                                                 BOLT, FLANGE, 6X16
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-5       RIGHT CRANKCASE COVER(CRF1000/CRF1000A)     19  95701-06025-00                          BOLT, FLANGE, 6X25 4 4 4 4 - - 2016.09.20
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)      1   11330-MJP-G80                                          COVER COMP., R. CRANKCASE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)      2   11335-MJP-G80                                                            ORIFICE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)      3   11337-MJP-G80                                                  COVER, OIL FILTER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)      4   11361-MJP-G80                                                       COVER, INNER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)      5   11375-MJP-G80                                                      CAP, R. COVER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)      6   11377-MJP-G80                                         COVER, OIL PRESSURE SENSOR
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)      7   11381-MJP-G80                                               COVER, R. RR. ENGINE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)      8   11385-MJF-A00                                                             COLLAR
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)      9   11394-MJP-G51                                         GASKET, R. CRANKCASE COVER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     10   15104-MGS-D20                                                     PIPE, OIL PASS
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     11   15412-MGS-D21                                                ELEMENT, OIL FILTER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     12   15414-MEB-670                                                 SPRING, OIL FILTER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     13   19200-MJP-G50                                                  PUMP COMP., WATER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     14   19226-MJP-G50                                            GASKET, WATER PUMP BODY
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     15   32157-MJP-G80                                                 STAY, HARNESS CLIP
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     16   32158-MJP-G80                                                 STAY, HARNESS CLIP
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     17   38810-MJP-G81                                      SENSOR ASSY., ANGLE(40DEGREE)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     18   90001-MJP-G50                                          BOLT, FLANGE SOCKET, 6X14
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     19   90002-MJP-G50                                          BOLT, FLANGE SOCKET, 6X18
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     20   90002-MJP-G80                                           BOLT, FLANGE SOCKET, 6X8
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     21   90004-MJP-G50                                          BOLT, FLANGE SOCKET, 6X28
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     22   90011-MGE-D00                                                   BOLT, KNOCK, 6MM
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     23   90031-MJP-G80                                                BOLT, SEALING, 12X8
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     24   90042-MJP-G80                                                BOLT, SPECIAL, 10MM
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     25   90085-MGC-920                                                BOLT, SPECIAL, 6X17
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     26   90404-HW1-670                                               WASHER, SEALING, 6MM
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     27   90488-425-000                                               WASHER, SEALING, 6MM
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     28   90545-KF0-000                                                       WASHER, 12MM
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     29   91004-MJP-G81                                      BEARING, RADIAL BALL, 40X52X7
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     30   91302-PA9-003                                             O-RING, 39.8X2.2(ARAI)
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     31   91307-MGE-D01                                                     O-RING, 81X2.2
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     32   91310-MGE-D01                                                   O-RING, 16.5X2.5
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     33   91311-RFH-003                                                    O-RING, 7.7X1.9
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     34   91315-MGS-D20                                                RING, BACK UP, 8X11
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     35   91315-MJP-G51                                                   SEAL, WATER PIPE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     36     94301-06100                                                    DOWEL PIN, 6X10
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     37     94301-08140                                                    DOWEL PIN, 8X14
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     38  95701-06020-00                                                 BOLT, FLANGE, 6X20
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     39  95701-06025-00                                                 BOLT, FLANGE, 6X25
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02      E-5-1               RIGHT CRANKCASE COVER(CRF1000D)     40  96100-63040-00                                              BEARING, RADIAL BALL,
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-6                               LINEAR SOLENOID      1   11338-MJP-G80                                            PLATE, SOLENOID STOPPER
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-6                               LINEAR SOLENOID      2   11362-MJP-G80                                                   PLATE, SEPARATOR
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-6                               LINEAR SOLENOID      3   11364-MJP-G80                                              GASKET, SOLENOID BODY
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-6                               LINEAR SOLENOID      4   11365-MJP-G80                                              BODY, LINEAR SOLENOID
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-6                               LINEAR SOLENOID      5   11366-MJP-G80                                             COVER, LINEAR SOLENOID
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-6                               LINEAR SOLENOID      6   11371-MGS-D20                                                      PACKING, BASE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-6                               LINEAR SOLENOID      7   11372-MGS-D20                                          FILTER COMP., SPOOL VALVE
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02        E-6                               LINEAR SOLENOID      8   11398-MJP-G81                                             GASKET, SOLENOID COVER
# ...
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      7 86643-MJP-G50ZB                                                            *TYPE1*                                                               ED,GS,TH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      7 86643-MJP-DA0ZA                                                            *TYPE1*                                                         ED,GS,KO,RU,TH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      7 86643-MJP-G50ZA                                                            *TYPE2*                                                               ED,GS,RU
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      8 86644-MJP-G50ZB                                      MARK , L. MIDDLE COWL *TYPE1*                                                                ED,GS,U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      8 86644-MJP-G50ZA                                                            *TYPE2*                                                               ED,RU,TH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      8 86644-MJP-DA0ZA                                                            *TYPE1*
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      8 86644-MJP-G50ZA                                                            *TYPE2*
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      8 86644-MJP-DA0ZA                                                            *TYPE1*                                                            ED,GS,KO,RU
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      8 86644-MJP-G50ZA                                                            *TYPE2*                                                          ED,GS,RU,TH,U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      8 86644-MJP-G50ZB                                                            *TYPE1*                                                               ED,GS,TH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      8 86644-MJP-DA0ZA                                                            *TYPE1*                                                         ED,GS,KO,RU,TH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      8 86644-MJP-G50ZA                                                            *TYPE2*                                                               ED,GS,RU
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      9 86831-MJP-G50ZC                                       MARK , R. SIDE COVER *TYPE1*                                                                ED,GS,U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      9 86831-MJP-G50ZB                                                            *TYPE2*                                                               ED,RU,TH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      9 86831-MJP-DA0ZA                                                            *TYPE1*
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      9 86831-MJP-G50ZB                                                            *TYPE2*
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      9 86831-MJP-DA0ZA                                                            *TYPE1*                                                            ED,GS,KO,RU
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      9 86831-MJP-G50ZB                                                            *TYPE2*                                                          ED,GS,RU,TH,U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      9 86831-MJP-G50ZC                                                            *TYPE1*                                                               ED,GS,TH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      9 86831-MJP-DA0ZA                                                            *TYPE1*                                                         ED,GS,KO,RU,TH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)      9 86831-MJP-G50ZB                                                            *TYPE2*                                                               ED,GS,RU
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)     10 86832-MJP-G50ZC                                       MARK , L. SIDE COVER *TYPE1*                                                                ED,GS,U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)     10 86832-MJP-G50ZB                                                            *TYPE2*                                                               ED,RU,TH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)     10 86832-MJP-DA0ZA                                                            *TYPE1*
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)     10 86832-MJP-G50ZB                                                            *TYPE2*
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)     10 86832-MJP-DA0ZA                                                            *TYPE1*                                                            ED,GS,KO,RU
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)     10 86832-MJP-G50ZB                                                            *TYPE2*                                                          ED,GS,RU,TH,U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)     10 86832-MJP-G50ZC                                                            *TYPE1*                                                               ED,GS,TH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)     10 86832-MJP-DA0ZA                                                            *TYPE1*                                                         ED,GS,KO,RU,TH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02       F-40                       MARK/EMBLEM(MONOCHROME)     10 86832-MJP-G50ZB                                                            *TYPE2*                                                               ED,GS,RU
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)      1 86101-MJP-G50ZA                                         MARK , HONDA(65MM) *TYPE1*                                             2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)      2 86102-MJP-G50ZA                                         MARK , HONDA(55MM) *TYPE1*                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)      3 86171-MJP-E50ZA                                      STRIPE , R. FUEL TANK *TYPE1*                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)      4 86172-MJP-E50ZA                                      STRIPE , L. FUEL TANK *TYPE1*                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)      5   86211-MJP-G50                                                  BADGE, R. PRODUCT                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)      6   86212-MJP-G50                                                  BADGE, L. PRODUCT                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)      7 86611-MJP-E50ZA                                     STRIPE , R. FR. FENDER *TYPE1*                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)      8 86612-MJP-E50ZA                                     STRIPE , L. FR. FENDER *TYPE1*                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)      9 86641-MJP-E50ZA                                   STRIPE A, R. MIDDLE COWL *TYPE1*                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)     10 86642-MJP-E50ZA                                   STRIPE A, L. MIDDLE COWL *TYPE1*                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)     11 86643-MJP-E50ZA                                   STRIPE B, R. MIDDLE COWL *TYPE1*                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)     12 86644-MJP-E50ZA                                   STRIPE B, L. MIDDLE COWL *TYPE1*                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)     13 86831-MJP-E50ZA                                     STRIPE , R. SIDE COVER *TYPE1*                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-1                         MARK/EMBLEM(TRICOLOR)     14 86832-MJP-E50ZA                                     STRIPE , L. SIDE COVER *TYPE1*                                         2CH,2ED,2GS,2IN,2KO,2RU,2TH,2U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)      1 86101-MJP-G50ZA                                         MARK , HONDA(65MM) *TYPE1*                                             3ED,3GS,3IN,3KO,3RU,3TH,3U
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)      2 86102-MJP-G50ZA                                         MARK , HONDA(55MM) *TYPE1*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)      3 86171-MJP-F50ZA                                     STRIPE A, R. FUEL TANK *TYPE1*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)      4 86172-MJP-F50ZA                                     STRIPE A, L. FUEL TANK *TYPE1*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)      5 86173-MJP-F50ZA                                     STRIPE B, R. FUEL TANK *TYPE1*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)      6 86174-MJP-F50ZA                                     STRIPE B, L. FUEL TANK *TYPE1*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)      7   86211-MJP-G50                                                  BADGE, R. PRODUCT                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)      8   86212-MJP-G50                                                  BADGE, L. PRODUCT                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)      9 86611-MJP-F50ZA                                     STRIPE , R. FR. FENDER *TYPE1*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)     10 86612-MJP-F50ZA                                     STRIPE , L. FR. FENDER *TYPE1*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)     11 86641-MJP-F50ZA                                   STRIPE A, R. MIDDLE COWL *TYPE1*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)     12 86642-MJP-F50ZA                                   STRIPE A, L. MIDDLE COWL *TYPE1*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)     13 86643-MJP-F50ZA                                   STRIPE B, R. MIDDLE COWL *TYPE1*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)     14 86644-MJP-F50ZA                                   STRIPE B, L. MIDDLE COWL *TYPE1*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)     15 86831-MJP-G50ZA                                       MARK , R. SIDE COVER *TYPE3*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
# CRF1000_13MJPG02 2022 Honda CRF1000 13MJPG02     F-40-2                        MARK/EMBLEM(CRF COLOR)     16 86832-MJP-G50ZA                                       MARK , L. SIDE COVER *TYPE3*                                         3ED,3GS,3IN,3KO,3RU,3TH,3U,4CH
